# %% [markdown]
# # avocado project

# %%
# importing libraries
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder, PowerTransformer
from math import sqrt
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score, classification_report, plot_roc_curve
from sklearn.metrics import r2_score, mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data= pd.read_csv("C:\\Users\diwak\\Downloads\\avocado\\avocado.csv")
data.head(5)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
data.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %%
data.shape
# Out:
# (18249, 14)

# %%
data= data.drop(columns=['Unnamed: 0','Date'])

# %%
data.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# std    9.862424e+05  7.461785e+05  2.439660e+05   17692.894652      0.939938
# min    0.000000e+00  0.000000e+00  0.000000e+00       0.000000   2015.000000
# 25%    5.088640e+03  2.849420e+03  1.274700e+02       0.000000   2015.000000
# 50%    3.974383e+04  2.636282e+04  2.647710e+03       0.000000   2016.000000
# 75%    1.107834e+05  8.333767e+04  2.202925e+04     132.500000   2017.000000
# max    1.937313e+07  1.338459e+07  5.719097e+06  551693.650000   2018.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  18249 non-null  float64
#  1   Total Volume  18249 non-null  float64
#  2   4046          18249 non-null  float64
#  3   4225          18249 non-null  float64
#  4   4770          18249 non-null  float64
#  5   Total Bags    18249 non-null  float64
#  6   Small Bags    18249 non-null  float64
#  7   Large Bags    18249 non-null  float64
#  8   XLarge Bags   18249 non-null  float64
#  9   type          18249 non-null  object
#  10  year          18249 non-null  int64
#  11  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(2)
# memory usage: 1.7+ MB

# %%
# checking for missing values
data.isna().sum()
# Out:
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
N_data= data.drop(columns=['region','type'])
C_data= data[['region','type']]

# %%
C_data.nunique()
# Out:
# region    54
# type       2
# dtype: int64

# %%
sns.countplot(x='type',data=data)
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
plt.figure(figsize=(15,15))
sns.swarmplot(x='type',y='region',data=data)
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.stripplot(x="AveragePrice",y="region",data=data)
plt.show()

# %%
plt.figure(figsize=(15,15))
x=data['Total Volume']
y=data['region']
plt.barh(y,x)
plt.show()

# %%
plt.figure(figsize=(8,8))
x=data['year']
y=data['Total Volume']
plt.bar(x,y)
plt.show()

# %%
#Plotting graphs for numerical data
plt.figure(figsize=(20,20))
plotnumber = 1
for column in N_data:
    if plotnumber <=10:
        ax= plt.subplot(3,4,plotnumber)
        sns.distplot(N_data[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#checking for skewness
data.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# year             0.215339
# dtype: float64

# %%
L_encoder = LabelEncoder()
for i in data.columns:
    if data[i].dtypes=='object':
        data[i]=L_encoder.fit_transform(data[i].values.reshape(-1,1))

# %%
data.head(10)
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
# 5          1.26      55979.78  1184.27   48067.99   43.61     6683.91
# 6          0.99      83453.76  1368.92   73672.72   93.26     8318.86
# 7          0.98     109428.33   703.75  101815.36   80.00     6829.22
# 8          1.02      99811.42  1022.15   87315.57   85.34    11388.36
# 9          1.07      74338.76   842.40   64757.44  113.00     8625.92
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region
# 0     8603.62       93.25          0.0     0  2015       0
# 1     9408.07       97.49          0.0     0  2015       0
# 2     8042.21      103.14          0.0     0  2015       0
# 3     5677.40      133.76          0.0     0  2015       0
# 4     5986.26      197.69          0.0     0  2015       0
# 5     6556.47      127.44          0.0     0  2015       0
# 6     8196.81      122.05          0.0     0  2015       0
# 7     6266.85      562.37          0.0     0  2015       0
# 8    11104.53      283.83          0.0     0  2015       0
# 9     8061.47      564.45          0.0     0  2015       0

# %%
# Checking for outliers using boxplot
plt.figure(figsize=(20,30))
graph =1
for column in data:
    if graph <=12:
        plt.subplot(4,3,graph)
        ax=sns.boxplot(data=data[column])
        plt.xlabel(column,fontsize=15)
    graph+=1
plt.show()

# %%
# Using z-score to detect and treat the outliers
features=data.drop('region',axis=1)
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(features))
threshold=3
outliers=np.where(z>3)
outliers
# Out:
# (array([  346,   359,   780, ..., 17304, 17402, 17428], dtype=int64),
#  array([2, 2, 8, ..., 0, 0, 0], dtype=int64))

# %%
clf_data=data.drop(outliers[0])
clf_data
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year  region
# 0         8603.62       93.25          0.0     0  2015       0
# 1         9408.07       97.49          0.0     0  2015       0
# 2         8042.21      103.14          0.0     0  2015       0
# 3         5677.40      133.76          0.0     0  2015       0
# 4         5986.26      197.69          0.0     0  2015       0
# ...           ...         ...          ...   ...   ...     ...
# 18244    13066.82      431.85          0.0     1  2018      53
# 18245     8940.04      324.80          0.0     1  2018      53
# 18246     9351.80       42.31          0.0     1  2018      53
# 18247    10919.54       50.00          0.0     1  2018      53
# 18248    11988.14       26.01          0.0     1  2018      53
#
# [17651 rows x 12 columns]

# %%
data_loss=((18248-17561)/18248)*100
data_loss
# Out:
# 3.7647961420429636

# %%
reg_features=data.drop('AveragePrice',axis=1)
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(reg_features))
threshold=3
reg_outliers = np.where(z>3)
reg_outliers
# Out:
# (array([ 346,  359,  780, ..., 9111, 9112, 9113], dtype=int64),
#  array([1, 1, 7, ..., 6, 6, 6], dtype=int64))

# %%
reg_data=data.drop(reg_outliers[0])
reg_data
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year  region
# 0         8603.62       93.25          0.0     0  2015       0
# 1         9408.07       97.49          0.0     0  2015       0
# 2         8042.21      103.14          0.0     0  2015       0
# 3         5677.40      133.76          0.0     0  2015       0
# 4         5986.26      197.69          0.0     0  2015       0
# ...           ...         ...          ...   ...   ...     ...
# 18244    13066.82      431.85          0.0     1  2018      53
# 18245     8940.04      324.80          0.0     1  2018      53
# 18246     9351.80       42.31          0.0     1  2018      53
# 18247    10919.54       50.00          0.0     1  2018      53
# 18248    11988.14       26.01          0.0     1  2018      53
#
# [17782 rows x 12 columns]

# %%
data_loss=((18248-17782)/18248)*100
data_loss
# Out:
# 2.5537045155633495

# %%
#checking for skewness
clf_data.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    3.767138
# 4046            4.909848
# 4225            4.455745
# 4770            5.117170
# Total Bags      4.066771
# Small Bags      4.222706
# Large Bags      5.053434
# XLarge Bags     6.135607
# type           -0.037741
# year            0.229976
# region          0.012798
# dtype: float64

# %%
reg_data.skew()
# Out:
# AveragePrice    0.560969
# Total Volume    3.782060
# 4046            4.928850
# 4225            4.472729
# 4770            5.137120
# Total Bags      4.082103
# Small Bags      4.238647
# Large Bags      5.072468
# XLarge Bags     6.159391
# type           -0.052210
# year            0.220792
# region          0.005773
# dtype: float64

# %%
# Plotting heat map to check for multicollinerity and labelv//s feature relationship
#Regression data
df_corr = reg_data.corr().abs()
plt.figure(figsize=(12,8))
sns.heatmap(df_corr, annot= True, annot_kws ={'size':10})
plt.show()

# %%
#Classification data
df_corr = clf_data.corr().abs()
plt.figure(figsize=(12,8))
sns.heatmap(df_corr, annot= True, annot_kws ={'size':10})
plt.show()

# %%
# Dividing data into feature and label
X= reg_data.drop(columns=['AveragePrice'])
Y= reg_data['AveragePrice']

# %%
#Applying PowerTransformer
pt = PowerTransformer()
X_scaled = pd.DataFrame(pt.fit_transform(X), columns=X.columns)

# %%
X_scaled
# Out:
#        Total Volume      4046      4225      4770  Total Bags  Small Bags  \
# 0         -0.065094 -0.649918  0.358278 -0.212550   -0.527445   -0.337064
# 1         -0.137269 -0.770067  0.276355 -0.165117   -0.488205   -0.301038
# 2          0.215503 -0.724508  0.656010  0.034215   -0.556204   -0.364044
# 3          0.029840 -0.625017  0.475615 -0.110976   -0.702370   -0.500341
# 4         -0.170456 -0.677083  0.268966 -0.100289   -0.675712   -0.479918
# ...             ...       ...       ...       ...         ...         ...
# 17777     -0.668931 -0.454078 -0.922232 -1.224990   -0.331042   -0.165765
# 17778     -0.762380 -0.610403 -0.665649 -1.224990   -0.499550   -0.321645
# 17779     -0.766344 -0.610350 -0.774395  0.455355   -0.493424   -0.303466
# 17780     -0.692595 -0.539211 -0.711605  0.455045   -0.424475   -0.240252
# 17781     -0.658062 -0.351503 -0.787209  0.168008   -0.383676   -0.201685
#
#        Large Bags  XLarge Bags      type          year    region
# 0       -0.775214    -0.675702 -1.026443 -5.271339e-13 -2.009197
# 1       -0.765237    -0.675702 -1.026443 -5.271339e-13 -2.009197
# 2       -0.752534    -0.675702 -1.026443 -5.271339e-13 -2.009197
# 3       -0.693012    -0.675702 -1.026443 -5.271339e-13 -2.009197
# 4       -0.600755    -0.675702 -1.026443 -5.271339e-13 -2.009197
# ...           ...          ...       ...           ...       ...
# 17777   -0.405895    -0.675702  0.974238  8.574808e-13  1.576337
# 17778   -0.478556    -0.675702  0.974238  8.574808e-13  1.576337
# 17779   -0.945246    -0.675702  0.974238  8.574808e-13  1.576337
# 17780   -0.910471    -0.675702  0.974238  8.574808e-13  1.576337
# 17781   -1.042930    -0.675702  0.974238  8.574808e-13  1.576337
#
# [17782 rows x 11 columns]

# %%
X_scaled.skew()
# Out:
# Total Volume   -0.006809
# 4046           -0.038259
# 4225           -0.043246
# 4770            0.028015
# Total Bags     -0.021531
# Small Bags     -0.024657
# Large Bags     -0.110061
# XLarge Bags     0.860603
# type           -0.052210
# year            0.000000
# region         -0.260077
# dtype: float64

# %%
#Using VIF to check for muliticolinearity:
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif['vif']=[variance_inflation_factor(X_scaled,i) for i in range(X_scaled.shape[1])]
vif['feature']= X.columns
vif
# Out:
#           vif       feature
# 0   52.032393  Total Volume
# 1    7.146315          4046
# 2   11.177169          4225
# 3    3.940581          4770
# 4   34.427518    Total Bags
# 5   16.630915    Small Bags
# 6    3.463038    Large Bags
# 7    2.042375   XLarge Bags
# 8    3.718984          type
# 9    1.323292          year
# 10   1.086840        region

# %%
X_scaled1= X_scaled.drop(columns=['Total Volume'])

# %%
#Calculating the VIFs again
vif1= pd.DataFrame()
vif1['vif']=[variance_inflation_factor(X_scaled1,i) for i in range(X_scaled1.shape[1])]
vif1['feature']= X_scaled1.columns
vif1
# Out:
#          vif      feature
# 0   3.724145         4046
# 1   4.273179         4225
# 2   3.927632         4770
# 3  24.467624   Total Bags
# 4  16.630575   Small Bags
# 5   3.420798   Large Bags
# 6   2.027475  XLarge Bags
# 7   3.504297         type
# 8   1.321877         year
# 9   1.080434       region

# %%
X_scaled2= X_scaled1.drop(columns=['Total Bags'])

# %%
#Calculating the VIFs again
vif2= pd.DataFrame()
vif2['vif']=[variance_inflation_factor(X_scaled2,i) for i in range(X_scaled2.shape[1])]
vif2['feature']= X_scaled2.columns
vif2
# Out:
#         vif      feature
# 0  3.705901         4046
# 1  4.130449         4225
# 2  3.927316         4770
# 3  4.071201   Small Bags
# 4  1.861905   Large Bags
# 5  2.027143  XLarge Bags
# 6  3.500862         type
# 7  1.299001         year
# 8  1.080434       region

# %%
#traintestsplit
lr = LinearRegression()
for i in range(0,1000):
    x_train,x_test,y_train,y_test = train_test_split (X_scaled2,Y, test_size=0.3, random_state = i)
    lr.fit(x_train,y_train)
    pred_train = lr.predict(x_train)
    pred_test = lr.predict(x_test)
    if round(r2_score(y_train,pred_train)*100)==round(r2_score(y_test,pred_test)*100):
        print ("At random state ",i,"the model performs well")
        print ("Acuraccy of training model :",r2_score(y_train,pred_train)*100)
        print ("Accuracy of testing model :",r2_score(y_test,pred_test)*100)
        print ("\n-----------------------------------------\n")
# Out:
# At random state  0 the model performs well
# Acuraccy of training model : 47.15866239002662
# Accuracy of testing model : 47.05898489184054
#
# -----------------------------------------
#
# At random state  3 the model performs well
# Acuraccy of training model : 47.134087908816916
# Accuracy of testing model : 47.13911719648556
#
# -----------------------------------------
#
# At random state  5 the model performs well
# Acuraccy of training model : 47.29258532069798
# Accuracy of testing model : 46.76047886029343
#
# -----------------------------------------
#
# At random state  6 the model performs well
# Acuraccy of training model : 46.973428945566596
# Accuracy of testing model : 47.44354755530473
#
# -----------------------------------------
#
# At random state  10 the model performs well
# Acuraccy of training model : 47.160467676988226
# Accuracy of testing model : 47.053925041307956
#
# -----------------------------------------
#
# At random state  14 the model performs well
# Acuraccy of training model : 47.23730305099314
# Accuracy of testing model : 46.89123676984644
#
# -----------------------------------------
#
# At random state  15 the model performs well
# Acuraccy of training model : 47.2144187762707
# Accuracy of testing model : 46.93888570406851
#
# -----------------------------------------
#
# At random state  16 the model performs well
# Acuraccy of training model : 47.349926826465136
# Accuracy of testing model : 46.533280505164356
#
# -----------------------------------------
#
# At random state  18 the model performs well
# Acuraccy of training model : 47.143925961111165
# Accuracy of testing model : 47.056996155193865
#
# -----------------------------------------
#
# At random state  19 the model performs well
# Acuraccy of training model : 47.05670611196023
# Accuracy of testing model : 47.31302247157036
#
# -----------------------------------------
#
# At random state  21 the model performs well
# Acuraccy of training model : 47.04816710816766
# Accuracy of testing model : 47.29139584761282
#
# -----------------------------------------
#
# At random state  24 the model performs well
# Acuraccy of training model : 47.197949118757364
# Accuracy of testing model : 46.952419097573014
#
# -----------------------------------------
#
# At random state  25 the model performs well
# Acuraccy of training model : 47.10984025679783
# Accuracy of testing model : 47.14392092627102
#
# -----------------------------------------
#
# At random state  26 the model performs well
# Acuraccy of training model : 47.01345895158757
# Accuracy of testing model : 47.36692911634791
#
# -----------------------------------------
#
# At random state  29 the model performs well
# Acuraccy of training model : 47.08422131397286
# Accuracy of testing model : 47.21414251509673
#
# -----------------------------------------
#
# At random state  30 the model performs well
# Acuraccy of training model : 47.210804644989054
# Accuracy of testing model : 46.92346219141618
#
# -----------------------------------------
#
# At random state  31 the model performs well
# Acuraccy of training model : 47.051162949745176
# Accuracy of testing model : 47.33444014805739
#
# -----------------------------------------
#
# At random state  32 the model performs well
# Acuraccy of training model : 47.20918208646477
# Accuracy of testing model : 46.88889652315965
#
# -----------------------------------------
#
# At random state  33 the model performs well
# Acuraccy of training model : 47.07036027840884
# Accuracy of testing model : 47.26341666922449
#
# -----------------------------------------
#
# At random state  34 the model performs well
# Acuraccy of training model : 47.40348159244942
# Accuracy of testing model : 46.52025387174491
#
# -----------------------------------------
#
# At random state  37 the model performs well
# Acuraccy of training model : 47.06559369743356
# Accuracy of testing model : 47.27652100296778
#
# -----------------------------------------
#
# At random state  38 the model performs well
# Acuraccy of training model : 47.140777176953854
# Accuracy of testing model : 47.09596520153335
#
# -----------------------------------------
#
# At random state  39 the model performs well
# Acuraccy of training model : 47.364324647104894
# Accuracy of testing model : 46.60120822709216
#
# -----------------------------------------
#
# At random state  40 the model performs well
# Acuraccy of training model : 46.97779850692023
# Accuracy of testing model : 47.49523774169746
#
# -----------------------------------------
#
# At random state  42 the model performs well
# Acuraccy of training model : 47.16089472053313
# Accuracy of testing model : 47.02621362495207
#
# -----------------------------------------
#
# At random state  44 the model performs well
# Acuraccy of training model : 47.07987271555724
# Accuracy of testing model : 47.18511736580779
#
# -----------------------------------------
#
# At random state  48 the model performs well
# Acuraccy of training model : 47.39522428923632
# Accuracy of testing model : 46.522061179630505
#
# -----------------------------------------
#
# At random state  55 the model performs well
# Acuraccy of training model : 47.287395997683234
# Accuracy of testing model : 46.71595528122251
#
# -----------------------------------------
#
# At random state  58 the model performs well
# Acuraccy of training model : 47.24402938915448
# Accuracy of testing model : 46.883098848620385
#
# -----------------------------------------
#
# At random state  64 the model performs well
# Acuraccy of training model : 47.25528181554498
# Accuracy of testing model : 46.87299916686596
#
# -----------------------------------------
#
# At random state  68 the model performs well
# Acuraccy of training model : 47.0277828071339
# Accuracy of testing model : 47.39560333741959
#
# -----------------------------------------
#
# At random state  69 the model performs well
# Acuraccy of training model : 47.16662892499015
# Accuracy of testing model : 47.013617395788074
#
# -----------------------------------------
#
# At random state  70 the model performs well
# Acuraccy of training model : 47.34328982644664
# Accuracy of testing model : 46.539102700203486
#
# -----------------------------------------
#
# At random state  72 the model performs well
# Acuraccy of training model : 47.1227087832353
# Accuracy of testing model : 47.15249078961933
#
# -----------------------------------------
#
# At random state  73 the model performs well
# Acuraccy of training model : 47.35412513007766
# Accuracy of testing model : 46.61133561209056
#
# -----------------------------------------
#
# At random state  74 the model performs well
# Acuraccy of training model : 47.253118756790094
# Accuracy of testing model : 46.860881328279326
#
# -----------------------------------------
#
# At random state  77 the model performs well
# Acuraccy of training model : 47.205611736225514
# Accuracy of testing model : 46.95196218615996
#
# -----------------------------------------
#
# At random state  79 the model performs well
# Acuraccy of training model : 47.05862448207475
# Accuracy of testing model : 47.32731613353928
#
# -----------------------------------------
#
# At random state  81 the model performs well
# Acuraccy of training model : 47.32938977324083
# Accuracy of testing model : 46.6809226978512
#
# -----------------------------------------
#
# At random state  82 the model performs well
# Acuraccy of training model : 47.23659286473176
# Accuracy of testing model : 46.870651826840515
#
# -----------------------------------------
#
# At random state  83 the model performs well
# Acuraccy of training model : 47.20494693536638
# Accuracy of testing model : 46.91110926372751
#
# -----------------------------------------
#
# At random state  84 the model performs well
# Acuraccy of training model : 47.15354224669907
# Accuracy of testing model : 47.057080923865755
#
# -----------------------------------------
#
# At random state  86 the model performs well
# Acuraccy of training model : 47.20628867802959
# Accuracy of testing model : 46.93474633017568
#
# -----------------------------------------
#
# At random state  88 the model performs well
# Acuraccy of training model : 47.2561183454701
# Accuracy of testing model : 46.817157470204094
#
# -----------------------------------------
#
# At random state  89 the model performs well
# Acuraccy of training model : 47.039949625010365
# Accuracy of testing model : 47.304174401955464
#
# -----------------------------------------
#
# At random state  90 the model performs well
# Acuraccy of training model : 47.37023391676088
# Accuracy of testing model : 46.58391134480087
#
# -----------------------------------------
#
# At random state  95 the model performs well
# Acuraccy of training model : 47.19981119580008
# Accuracy of testing model : 46.9572685088533
#
# -----------------------------------------
#
# At random state  96 the model performs well
# Acuraccy of training model : 47.315213301737515
# Accuracy of testing model : 46.67534945153255
#
# -----------------------------------------
#
# At random state  98 the model performs well
# Acuraccy of training model : 47.24915116314256
# Accuracy of testing model : 46.84753679500695
#
# -----------------------------------------
#
# At random state  103 the model performs well
# Acuraccy of training model : 47.1519112620628
# Accuracy of testing model : 47.030787525170204
#
# -----------------------------------------
#
# At random state  105 the model performs well
# Acuraccy of training model : 47.3156401354238
# Accuracy of testing model : 46.71429310609698
#
# -----------------------------------------
#
# At random state  106 the model performs well
# Acuraccy of training model : 47.12084791924551
# Accuracy of testing model : 47.15485746407243
#
# -----------------------------------------
#
# At random state  107 the model performs well
# Acuraccy of training model : 47.06046652930651
# Accuracy of testing model : 47.27034758325335
#
# -----------------------------------------
#
# At random state  109 the model performs well
# Acuraccy of training model : 47.35963065774844
# Accuracy of testing model : 46.5958715067757
#
# -----------------------------------------
#
# At random state  111 the model performs well
# Acuraccy of training model : 47.30191800350497
# Accuracy of testing model : 46.68843626031707
#
# -----------------------------------------
#
# At random state  113 the model performs well
# Acuraccy of training model : 46.99921806707684
# Accuracy of testing model : 47.44330115062052
#
# -----------------------------------------
#
# At random state  114 the model performs well
# Acuraccy of training model : 47.078449883146114
# Accuracy of testing model : 47.26212151895402
#
# -----------------------------------------
#
# At random state  117 the model performs well
# Acuraccy of training model : 47.041649821922405
# Accuracy of testing model : 47.33293915647342
#
# -----------------------------------------
#
# At random state  118 the model performs well
# Acuraccy of training model : 47.107764389664496
# Accuracy of testing model : 47.18585977062799
#
# -----------------------------------------
#
# At random state  119 the model performs well
# Acuraccy of training model : 47.22794690430728
# Accuracy of testing model : 46.88703392761007
#
# -----------------------------------------
#
# At random state  120 the model performs well
# Acuraccy of training model : 47.37547052156062
# Accuracy of testing model : 46.540795534294
#
# -----------------------------------------
#
# At random state  123 the model performs well
# Acuraccy of training model : 47.22449699814681
# Accuracy of testing model : 46.88612632046322
#
# -----------------------------------------
#
# At random state  124 the model performs well
# Acuraccy of training model : 47.158993614132726
# Accuracy of testing model : 47.05070173161479
#
# -----------------------------------------
#
# At random state  125 the model performs well
# Acuraccy of training model : 47.220718589412535
# Accuracy of testing model : 46.80637470925559
#
# -----------------------------------------
#
# At random state  130 the model performs well
# Acuraccy of training model : 47.08744603554816
# Accuracy of testing model : 47.199101226776506
#
# -----------------------------------------
#
# At random state  133 the model performs well
# Acuraccy of training model : 47.053497970853044
# Accuracy of testing model : 47.2637286196402
#
# -----------------------------------------
#
# At random state  134 the model performs well
# Acuraccy of training model : 47.239812838413044
# Accuracy of testing model : 46.87060777355793
#
# -----------------------------------------
#
# At random state  139 the model performs well
# Acuraccy of training model : 47.30059837153272
# Accuracy of testing model : 46.69762658052754
#
# -----------------------------------------
#
# At random state  141 the model performs well
# Acuraccy of training model : 47.03467291763408
# Accuracy of testing model : 47.301903333926
#
# -----------------------------------------
#
# At random state  144 the model performs well
# Acuraccy of training model : 47.08962146589633
# Accuracy of testing model : 47.22961384109096
#
# -----------------------------------------
#
# At random state  148 the model performs well
# Acuraccy of training model : 47.23399995766728
# Accuracy of testing model : 46.892247446161996
#
# -----------------------------------------
#
# At random state  149 the model performs well
# Acuraccy of training model : 47.37168077555975
# Accuracy of testing model : 46.5674230545287
#
# -----------------------------------------
#
# At random state  151 the model performs well
# Acuraccy of training model : 47.31119014622792
# Accuracy of testing model : 46.703512515164334
#
# -----------------------------------------
#
# At random state  152 the model performs well
# Acuraccy of training model : 47.07629059998916
# Accuracy of testing model : 47.213172581103976
#
# -----------------------------------------
#
# At random state  153 the model performs well
# Acuraccy of training model : 47.23501314026781
# Accuracy of testing model : 46.879730314417245
#
# -----------------------------------------
#
# At random state  154 the model performs well
# Acuraccy of training model : 47.33946713370977
# Accuracy of testing model : 46.53620001405518
#
# -----------------------------------------
#
# At random state  155 the model performs well
# Acuraccy of training model : 47.23193870373012
# Accuracy of testing model : 46.844081256083825
#
# -----------------------------------------
#
# At random state  156 the model performs well
# Acuraccy of training model : 47.351778559058786
# Accuracy of testing model : 46.643883345642145
#
# -----------------------------------------
#
# At random state  160 the model performs well
# Acuraccy of training model : 47.34872039746732
# Accuracy of testing model : 46.59361378672866
#
# -----------------------------------------
#
# At random state  162 the model performs well
# Acuraccy of training model : 46.98495823850013
# Accuracy of testing model : 47.46773194779684
#
# -----------------------------------------
#
# At random state  165 the model performs well
# Acuraccy of training model : 47.10964851119602
# Accuracy of testing model : 47.149849665263865
#
# -----------------------------------------
#
# At random state  167 the model performs well
# Acuraccy of training model : 47.12574492734939
# Accuracy of testing model : 47.15450346263055
#
# -----------------------------------------
#
# At random state  168 the model performs well
# Acuraccy of training model : 47.39194677406993
# Accuracy of testing model : 46.53042802738816
#
# -----------------------------------------
#
# At random state  169 the model performs well
# Acuraccy of training model : 47.08417602662131
# Accuracy of testing model : 47.21603521058883
#
# -----------------------------------------
#
# At random state  170 the model performs well
# Acuraccy of training model : 47.238868231224906
# Accuracy of testing model : 46.841430377223695
#
# -----------------------------------------
#
# At random state  171 the model performs well
# Acuraccy of training model : 47.312108643878915
# Accuracy of testing model : 46.714868040761814
#
# -----------------------------------------
#
# At random state  174 the model performs well
# Acuraccy of training model : 46.99713310996425
# Accuracy of testing model : 47.4601255690494
#
# -----------------------------------------
#
# At random state  175 the model performs well
# Acuraccy of training model : 46.979302136834534
# Accuracy of testing model : 47.49565749905964
#
# -----------------------------------------
#
# At random state  177 the model performs well
# Acuraccy of training model : 46.95858139775623
# Accuracy of testing model : 47.48965465064278
#
# -----------------------------------------
#
# At random state  181 the model performs well
# Acuraccy of training model : 47.12658366964555
# Accuracy of testing model : 47.14993289164398
#
# -----------------------------------------
#
# At random state  182 the model performs well
# Acuraccy of training model : 46.98992894051383
# Accuracy of testing model : 47.43183289140328
#
# -----------------------------------------
#
# At random state  183 the model performs well
# Acuraccy of training model : 47.07696501348671
# Accuracy of testing model : 47.24409830311426
#
# -----------------------------------------
#
# At random state  192 the model performs well
# Acuraccy of training model : 47.1797985405119
# Accuracy of testing model : 46.992306204051914
#
# -----------------------------------------
#
# At random state  193 the model performs well
# Acuraccy of training model : 47.33670417517622
# Accuracy of testing model : 46.65077194196474
#
# -----------------------------------------
#
# At random state  194 the model performs well
# Acuraccy of training model : 47.16700622940273
# Accuracy of testing model : 47.008855701698195
#
# -----------------------------------------
#
# At random state  198 the model performs well
# Acuraccy of training model : 47.125442561209276
# Accuracy of testing model : 47.14881385724075
#
# -----------------------------------------
#
# At random state  199 the model performs well
# Acuraccy of training model : 47.25886573127988
# Accuracy of testing model : 46.81924928260934
#
# -----------------------------------------
#
# At random state  201 the model performs well
# Acuraccy of training model : 47.2189305291158
# Accuracy of testing model : 46.90844039955285
#
# -----------------------------------------
#
# At random state  202 the model performs well
# Acuraccy of training model : 47.28912322886975
# Accuracy of testing model : 46.76950183303386
#
# -----------------------------------------
#
# At random state  204 the model performs well
# Acuraccy of training model : 47.0130366472143
# Accuracy of testing model : 47.38378710820881
#
# -----------------------------------------
#
# At random state  205 the model performs well
# Acuraccy of training model : 47.07003730780831
# Accuracy of testing model : 47.29447485132335
#
# -----------------------------------------
#
# At random state  207 the model performs well
# Acuraccy of training model : 47.03493047820333
# Accuracy of testing model : 47.36403483335175
#
# -----------------------------------------
#
# At random state  208 the model performs well
# Acuraccy of training model : 47.22737757787833
# Accuracy of testing model : 46.88493989179251
#
# -----------------------------------------
#
# At random state  209 the model performs well
# Acuraccy of training model : 47.36937883440092
# Accuracy of testing model : 46.58841278883163
#
# -----------------------------------------
#
# At random state  211 the model performs well
# Acuraccy of training model : 47.19858185765089
# Accuracy of testing model : 46.9590259445108
#
# -----------------------------------------
#
# At random state  212 the model performs well
# Acuraccy of training model : 47.0794226846451
# Accuracy of testing model : 47.27387889783628
#
# -----------------------------------------
#
# At random state  213 the model performs well
# Acuraccy of training model : 47.15802513519963
# Accuracy of testing model : 47.039200194081374
#
# -----------------------------------------
#
# At random state  215 the model performs well
# Acuraccy of training model : 47.03600869144072
# Accuracy of testing model : 47.31651486785017
#
# -----------------------------------------
#
# At random state  216 the model performs well
# Acuraccy of training model : 47.351195351318346
# Accuracy of testing model : 46.55295453395981
#
# -----------------------------------------
#
# At random state  221 the model performs well
# Acuraccy of training model : 47.34755160486299
# Accuracy of testing model : 46.578058595542856
#
# -----------------------------------------
#
# At random state  224 the model performs well
# Acuraccy of training model : 47.19138599475031
# Accuracy of testing model : 47.000124859994564
#
# -----------------------------------------
#
# At random state  227 the model performs well
# Acuraccy of training model : 47.29704922634603
# Accuracy of testing model : 46.75184054738284
#
# -----------------------------------------
#
# At random state  229 the model performs well
# Acuraccy of training model : 47.29304324957783
# Accuracy of testing model : 46.72860344197306
#
# -----------------------------------------
#
# At random state  231 the model performs well
# Acuraccy of training model : 47.06490419327207
# Accuracy of testing model : 47.29082038950322
#
# -----------------------------------------
#
# At random state  234 the model performs well
# Acuraccy of training model : 47.08506756707058
# Accuracy of testing model : 47.24565500553665
#
# -----------------------------------------
#
# At random state  235 the model performs well
# Acuraccy of training model : 47.114690795119685
# Accuracy of testing model : 47.119108643054005
#
# -----------------------------------------
#
# At random state  236 the model performs well
# Acuraccy of training model : 47.28850489734294
# Accuracy of testing model : 46.76340854699317
#
# -----------------------------------------
#
# At random state  239 the model performs well
# Acuraccy of training model : 46.97563467102651
# Accuracy of testing model : 47.4811370622648
#
# -----------------------------------------
#
# At random state  242 the model performs well
# Acuraccy of training model : 47.340556033763015
# Accuracy of testing model : 46.52245694717902
#
# -----------------------------------------
#
# At random state  243 the model performs well
# Acuraccy of training model : 47.253467662429394
# Accuracy of testing model : 46.8386314944515
#
# -----------------------------------------
#
# At random state  247 the model performs well
# Acuraccy of training model : 47.37137738762591
# Accuracy of testing model : 46.585989830181695
#
# -----------------------------------------
#
# At random state  248 the model performs well
# Acuraccy of training model : 47.030899668572644
# Accuracy of testing model : 47.36020534748116
#
# -----------------------------------------
#
# At random state  249 the model performs well
# Acuraccy of training model : 47.27924567008981
# Accuracy of testing model : 46.79762369367726
#
# -----------------------------------------
#
# At random state  251 the model performs well
# Acuraccy of training model : 47.12645093391906
# Accuracy of testing model : 47.156588627565185
#
# -----------------------------------------
#
# At random state  254 the model performs well
# Acuraccy of training model : 47.27959242455931
# Accuracy of testing model : 46.77388761217556
#
# -----------------------------------------
#
# At random state  255 the model performs well
# Acuraccy of training model : 47.02049229684644
# Accuracy of testing model : 47.398405482418504
#
# -----------------------------------------
#
# At random state  256 the model performs well
# Acuraccy of training model : 47.25654017220322
# Accuracy of testing model : 46.82802261207396
#
# -----------------------------------------
#
# At random state  258 the model performs well
# Acuraccy of training model : 47.21106732777197
# Accuracy of testing model : 46.9114043660314
#
# -----------------------------------------
#
# At random state  260 the model performs well
# Acuraccy of training model : 47.147791011279736
# Accuracy of testing model : 47.06639293251831
#
# -----------------------------------------
#
# At random state  261 the model performs well
# Acuraccy of training model : 47.01265327285324
# Accuracy of testing model : 47.38530892785653
#
# -----------------------------------------
#
# At random state  265 the model performs well
# Acuraccy of training model : 47.1525445489086
# Accuracy of testing model : 47.05563363208574
#
# -----------------------------------------
#
# At random state  274 the model performs well
# Acuraccy of training model : 46.98774761196767
# Accuracy of testing model : 47.44497535908522
#
# -----------------------------------------
#
# At random state  279 the model performs well
# Acuraccy of training model : 47.082722935794976
# Accuracy of testing model : 47.22321998572937
#
# -----------------------------------------
#
# At random state  286 the model performs well
# Acuraccy of training model : 47.20980742213538
# Accuracy of testing model : 46.885012312372524
#
# -----------------------------------------
#
# At random state  287 the model performs well
# Acuraccy of training model : 47.03569130426245
# Accuracy of testing model : 47.36644600076586
#
# -----------------------------------------
#
# At random state  289 the model performs well
# Acuraccy of training model : 47.126566214218016
# Accuracy of testing model : 47.12928060553602
#
# -----------------------------------------
#
# At random state  290 the model performs well
# Acuraccy of training model : 47.19430714322124
# Accuracy of testing model : 46.95883561453651
#
# -----------------------------------------
#
# At random state  293 the model performs well
# Acuraccy of training model : 47.11334539237259
# Accuracy of testing model : 47.135806097477854
#
# -----------------------------------------
#
# At random state  296 the model performs well
# Acuraccy of training model : 47.01428078700155
# Accuracy of testing model : 47.40194144765548
#
# -----------------------------------------
#
# At random state  298 the model performs well
# Acuraccy of training model : 47.26203941070257
# Accuracy of testing model : 46.82757792935919
#
# -----------------------------------------
#
# At random state  301 the model performs well
# Acuraccy of training model : 47.0346069386123
# Accuracy of testing model : 47.360985213119335
#
# -----------------------------------------
#
# At random state  302 the model performs well
# Acuraccy of training model : 47.203536911471886
# Accuracy of testing model : 46.90860842583917
#
# -----------------------------------------
#
# At random state  304 the model performs well
# Acuraccy of training model : 47.21622816411583
# Accuracy of testing model : 46.93975095237344
#
# -----------------------------------------
#
# At random state  306 the model performs well
# Acuraccy of training model : 47.03317095315814
# Accuracy of testing model : 47.333485962213885
#
# -----------------------------------------
#
# At random state  307 the model performs well
# Acuraccy of training model : 47.140824527334544
# Accuracy of testing model : 47.0843411483382
#
# -----------------------------------------
#
# At random state  308 the model performs well
# Acuraccy of training model : 47.03506980409367
# Accuracy of testing model : 47.338550247557855
#
# -----------------------------------------
#
# At random state  311 the model performs well
# Acuraccy of training model : 47.193769359696034
# Accuracy of testing model : 46.95943740754941
#
# -----------------------------------------
#
# At random state  312 the model performs well
# Acuraccy of training model : 47.31668455375503
# Accuracy of testing model : 46.68539098934947
#
# -----------------------------------------
#
# At random state  316 the model performs well
# Acuraccy of training model : 46.96788353846896
# Accuracy of testing model : 47.4964169008605
#
# -----------------------------------------
#
# At random state  317 the model performs well
# Acuraccy of training model : 47.25889230841587
# Accuracy of testing model : 46.79910569948505
#
# -----------------------------------------
#
# At random state  318 the model performs well
# Acuraccy of training model : 47.04477919428691
# Accuracy of testing model : 47.34821622941253
#
# -----------------------------------------
#
# At random state  321 the model performs well
# Acuraccy of training model : 47.13044998105423
# Accuracy of testing model : 47.118066945344175
#
# -----------------------------------------
#
# At random state  325 the model performs well
# Acuraccy of training model : 47.22139401996689
# Accuracy of testing model : 46.92196056486482
#
# -----------------------------------------
#
# At random state  326 the model performs well
# Acuraccy of training model : 47.14467843479556
# Accuracy of testing model : 47.08444573551264
#
# -----------------------------------------
#
# At random state  328 the model performs well
# Acuraccy of training model : 47.00529522596069
# Accuracy of testing model : 47.39092122505302
#
# -----------------------------------------
#
# At random state  330 the model performs well
# Acuraccy of training model : 47.111997280170115
# Accuracy of testing model : 47.156448518423446
#
# -----------------------------------------
#
# At random state  331 the model performs well
# Acuraccy of training model : 47.23969549132403
# Accuracy of testing model : 46.84710056701068
#
# -----------------------------------------
#
# At random state  334 the model performs well
# Acuraccy of training model : 47.08981347075731
# Accuracy of testing model : 47.216193291383426
#
# -----------------------------------------
#
# At random state  338 the model performs well
# Acuraccy of training model : 47.01581896942738
# Accuracy of testing model : 47.379431990102326
#
# -----------------------------------------
#
# At random state  341 the model performs well
# Acuraccy of training model : 47.129680718434386
# Accuracy of testing model : 47.12361331239448
#
# -----------------------------------------
#
# At random state  342 the model performs well
# Acuraccy of training model : 47.242756435506514
# Accuracy of testing model : 46.85677171098083
#
# -----------------------------------------
#
# At random state  343 the model performs well
# Acuraccy of training model : 47.01553893640704
# Accuracy of testing model : 47.38878864868125
#
# -----------------------------------------
#
# At random state  345 the model performs well
# Acuraccy of training model : 47.34226888223713
# Accuracy of testing model : 46.6490094661977
#
# -----------------------------------------
#
# At random state  346 the model performs well
# Acuraccy of training model : 47.02150964063604
# Accuracy of testing model : 47.337234102254946
#
# -----------------------------------------
#
# At random state  348 the model performs well
# Acuraccy of training model : 47.1452508640431
# Accuracy of testing model : 47.09444929267684
#
# -----------------------------------------
#
# At random state  349 the model performs well
# Acuraccy of training model : 47.223138774536835
# Accuracy of testing model : 46.91477682199652
#
# -----------------------------------------
#
# At random state  350 the model performs well
# Acuraccy of training model : 47.001422258569534
# Accuracy of testing model : 47.43519690862564
#
# -----------------------------------------
#
# At random state  351 the model performs well
# Acuraccy of training model : 47.19388629322522
# Accuracy of testing model : 46.941329553525904
#
# -----------------------------------------
#
# At random state  359 the model performs well
# Acuraccy of training model : 47.236691164639474
# Accuracy of testing model : 46.89722177681319
#
# -----------------------------------------
#
# At random state  360 the model performs well
# Acuraccy of training model : 47.27435038982829
# Accuracy of testing model : 46.745691282717516
#
# -----------------------------------------
#
# At random state  361 the model performs well
# Acuraccy of training model : 47.33001824768069
# Accuracy of testing model : 46.6249550304619
#
# -----------------------------------------
#
# At random state  362 the model performs well
# Acuraccy of training model : 47.004645549444
# Accuracy of testing model : 47.431317655156136
#
# -----------------------------------------
#
# At random state  368 the model performs well
# Acuraccy of training model : 47.099339904580006
# Accuracy of testing model : 47.20524114615383
#
# -----------------------------------------
#
# At random state  372 the model performs well
# Acuraccy of training model : 47.390821351679115
# Accuracy of testing model : 46.529549674497694
#
# -----------------------------------------
#
# At random state  378 the model performs well
# Acuraccy of training model : 46.99137625100839
# Accuracy of testing model : 47.485112665241424
#
# -----------------------------------------
#
# At random state  380 the model performs well
# Acuraccy of training model : 47.199634042325386
# Accuracy of testing model : 46.956983976719044
#
# -----------------------------------------
#
# At random state  383 the model performs well
# Acuraccy of training model : 47.1100730640485
# Accuracy of testing model : 47.17372165873046
#
# -----------------------------------------
#
# At random state  384 the model performs well
# Acuraccy of training model : 47.38561442840164
# Accuracy of testing model : 46.51982708701847
#
# -----------------------------------------
#
# At random state  385 the model performs well
# Acuraccy of training model : 47.26500690741262
# Accuracy of testing model : 46.80853172835672
#
# -----------------------------------------
#
# At random state  386 the model performs well
# Acuraccy of training model : 46.97512066916344
# Accuracy of testing model : 47.4544299198323
#
# -----------------------------------------
#
# At random state  389 the model performs well
# Acuraccy of training model : 47.16767925299591
# Accuracy of testing model : 47.045912626969425
#
# -----------------------------------------
#
# At random state  390 the model performs well
# Acuraccy of training model : 47.02057199141317
# Accuracy of testing model : 47.370532125543754
#
# -----------------------------------------
#
# At random state  391 the model performs well
# Acuraccy of training model : 47.32255583887996
# Accuracy of testing model : 46.696415870375205
#
# -----------------------------------------
#
# At random state  392 the model performs well
# Acuraccy of training model : 47.20796727710722
# Accuracy of testing model : 46.94608196007146
#
# -----------------------------------------
#
# At random state  393 the model performs well
# Acuraccy of training model : 47.01600353533665
# Accuracy of testing model : 47.40027055813307
#
# -----------------------------------------
#
# At random state  396 the model performs well
# Acuraccy of training model : 46.97098028187274
# Accuracy of testing model : 47.49298044918859
#
# -----------------------------------------
#
# At random state  397 the model performs well
# Acuraccy of training model : 47.34871635715543
# Accuracy of testing model : 46.595609051944855
#
# -----------------------------------------
#
# At random state  398 the model performs well
# Acuraccy of training model : 47.221400867443606
# Accuracy of testing model : 46.9219773300118
#
# -----------------------------------------
#
# At random state  399 the model performs well
# Acuraccy of training model : 47.353110270649445
# Accuracy of testing model : 46.60201632207698
#
# -----------------------------------------
#
# At random state  400 the model performs well
# Acuraccy of training model : 47.169962460841575
# Accuracy of testing model : 47.006354765495686
#
# -----------------------------------------
#
# At random state  401 the model performs well
# Acuraccy of training model : 47.28279176552713
# Accuracy of testing model : 46.7644714688513
#
# -----------------------------------------
#
# At random state  403 the model performs well
# Acuraccy of training model : 47.16827498822818
# Accuracy of testing model : 47.05437129604224
#
# -----------------------------------------
#
# At random state  404 the model performs well
# Acuraccy of training model : 47.121960168491206
# Accuracy of testing model : 47.15740630558809
#
# -----------------------------------------
#
# At random state  405 the model performs well
# Acuraccy of training model : 47.26338082260639
# Accuracy of testing model : 46.826824579669015
#
# -----------------------------------------
#
# At random state  407 the model performs well
# Acuraccy of training model : 47.386504235671
# Accuracy of testing model : 46.51125436250547
#
# -----------------------------------------
#
# At random state  408 the model performs well
# Acuraccy of training model : 47.20201808334584
# Accuracy of testing model : 46.930277337528445
#
# -----------------------------------------
#
# At random state  409 the model performs well
# Acuraccy of training model : 47.25321468123168
# Accuracy of testing model : 46.809941398406565
#
# -----------------------------------------
#
# At random state  410 the model performs well
# Acuraccy of training model : 47.37107761284376
# Accuracy of testing model : 46.526821443467384
#
# -----------------------------------------
#
# At random state  415 the model performs well
# Acuraccy of training model : 47.348249019704184
# Accuracy of testing model : 46.609312175563936
#
# -----------------------------------------
#
# At random state  416 the model performs well
# Acuraccy of training model : 47.07631798268188
# Accuracy of testing model : 47.27213567756272
#
# -----------------------------------------
#
# At random state  422 the model performs well
# Acuraccy of training model : 47.17666120242503
# Accuracy of testing model : 47.01725266290029
#
# -----------------------------------------
#
# At random state  424 the model performs well
# Acuraccy of training model : 47.10387575464562
# Accuracy of testing model : 47.18477450263443
#
# -----------------------------------------
#
# At random state  425 the model performs well
# Acuraccy of training model : 47.04617801685874
# Accuracy of testing model : 47.34144926038606
#
# -----------------------------------------
#
# At random state  431 the model performs well
# Acuraccy of training model : 47.16271544709877
# Accuracy of testing model : 46.956344931904596
#
# -----------------------------------------
#
# At random state  433 the model performs well
# Acuraccy of training model : 46.997912969179744
# Accuracy of testing model : 47.44108451372462
#
# -----------------------------------------
#
# At random state  434 the model performs well
# Acuraccy of training model : 47.25406746343892
# Accuracy of testing model : 46.847851397543
#
# -----------------------------------------
#
# At random state  436 the model performs well
# Acuraccy of training model : 47.19452263558226
# Accuracy of testing model : 46.958360823686654
#
# -----------------------------------------
#
# At random state  439 the model performs well
# Acuraccy of training model : 47.01125463593139
# Accuracy of testing model : 47.39999330740451
#
# -----------------------------------------
#
# At random state  440 the model performs well
# Acuraccy of training model : 47.06336015991507
# Accuracy of testing model : 47.31406511751462
#
# -----------------------------------------
#
# At random state  442 the model performs well
# Acuraccy of training model : 46.98417789964484
# Accuracy of testing model : 47.49223312777088
#
# -----------------------------------------
#
# At random state  444 the model performs well
# Acuraccy of training model : 47.22764826992958
# Accuracy of testing model : 46.92117454417678
#
# -----------------------------------------
#
# At random state  445 the model performs well
# Acuraccy of training model : 47.18795209046051
# Accuracy of testing model : 46.97004166653951
#
# -----------------------------------------
#
# At random state  446 the model performs well
# Acuraccy of training model : 47.300494763841115
# Accuracy of testing model : 46.73098627334624
#
# -----------------------------------------
#
# At random state  451 the model performs well
# Acuraccy of training model : 47.18904264849127
# Accuracy of testing model : 46.99137996789735
#
# -----------------------------------------
#
# At random state  452 the model performs well
# Acuraccy of training model : 47.10438277272784
# Accuracy of testing model : 47.215854155320116
#
# -----------------------------------------
#
# At random state  456 the model performs well
# Acuraccy of training model : 47.18633993955036
# Accuracy of testing model : 46.97376105797571
#
# -----------------------------------------
#
# At random state  457 the model performs well
# Acuraccy of training model : 47.3857613898365
# Accuracy of testing model : 46.51891257023537
#
# -----------------------------------------
#
# At random state  460 the model performs well
# Acuraccy of training model : 47.03038706384244
# Accuracy of testing model : 47.35815175806872
#
# -----------------------------------------
#
# At random state  461 the model performs well
# Acuraccy of training model : 46.98427654123595
# Accuracy of testing model : 47.43906675222232
#
# -----------------------------------------
#
# At random state  462 the model performs well
# Acuraccy of training model : 47.225050900925744
# Accuracy of testing model : 46.881440113919105
#
# -----------------------------------------
#
# At random state  464 the model performs well
# Acuraccy of training model : 47.14370926125846
# Accuracy of testing model : 47.078239136753055
#
# -----------------------------------------
#
# At random state  466 the model performs well
# Acuraccy of training model : 47.31463839620624
# Accuracy of testing model : 46.70460405212249
#
# -----------------------------------------
#
# At random state  467 the model performs well
# Acuraccy of training model : 47.26127295890247
# Accuracy of testing model : 46.80743535799123
#
# -----------------------------------------
#
# At random state  468 the model performs well
# Acuraccy of training model : 47.18589053013077
# Accuracy of testing model : 46.99783147427643
#
# -----------------------------------------
#
# At random state  469 the model performs well
# Acuraccy of training model : 47.33689743649666
# Accuracy of testing model : 46.657641664627945
#
# -----------------------------------------
#
# At random state  470 the model performs well
# Acuraccy of training model : 47.29443467906164
# Accuracy of testing model : 46.752143412314815
#
# -----------------------------------------
#
# At random state  471 the model performs well
# Acuraccy of training model : 47.068285525354995
# Accuracy of testing model : 47.27482426888684
#
# -----------------------------------------
#
# At random state  472 the model performs well
# Acuraccy of training model : 47.3520017788034
# Accuracy of testing model : 46.61889520921903
#
# -----------------------------------------
#
# At random state  475 the model performs well
# Acuraccy of training model : 47.1715656789512
# Accuracy of testing model : 47.04292045308064
#
# -----------------------------------------
#
# At random state  476 the model performs well
# Acuraccy of training model : 47.13502194696532
# Accuracy of testing model : 47.077795394039136
#
# -----------------------------------------
#
# At random state  478 the model performs well
# Acuraccy of training model : 47.139602836340664
# Accuracy of testing model : 47.07313586838183
#
# -----------------------------------------
#
# At random state  481 the model performs well
# Acuraccy of training model : 47.34347363475814
# Accuracy of testing model : 46.594461392968675
#
# -----------------------------------------
#
# At random state  483 the model performs well
# Acuraccy of training model : 47.39785496144662
# Accuracy of testing model : 46.50278299738411
#
# -----------------------------------------
#
# At random state  486 the model performs well
# Acuraccy of training model : 47.13349541567945
# Accuracy of testing model : 47.128558719305545
#
# -----------------------------------------
#
# At random state  488 the model performs well
# Acuraccy of training model : 47.18956061625709
# Accuracy of testing model : 46.97311709017832
#
# -----------------------------------------
#
# At random state  489 the model performs well
# Acuraccy of training model : 47.115214930360835
# Accuracy of testing model : 47.17381816543524
#
# -----------------------------------------
#
# At random state  491 the model performs well
# Acuraccy of training model : 47.16847224966051
# Accuracy of testing model : 47.06328994515967
#
# -----------------------------------------
#
# At random state  492 the model performs well
# Acuraccy of training model : 47.01599590201443
# Accuracy of testing model : 47.38598174744786
#
# -----------------------------------------
#
# At random state  493 the model performs well
# Acuraccy of training model : 47.15186754253469
# Accuracy of testing model : 47.040695235869364
#
# -----------------------------------------
#
# At random state  500 the model performs well
# Acuraccy of training model : 46.9671048151035
# Accuracy of testing model : 47.4694904403838
#
# -----------------------------------------
#
# At random state  501 the model performs well
# Acuraccy of training model : 47.06902879350974
# Accuracy of testing model : 47.26629000074196
#
# -----------------------------------------
#
# At random state  503 the model performs well
# Acuraccy of training model : 47.127406105653755
# Accuracy of testing model : 47.09796644032417
#
# -----------------------------------------
#
# At random state  506 the model performs well
# Acuraccy of training model : 47.29858758892621
# Accuracy of testing model : 46.715638714523166
#
# -----------------------------------------
#
# At random state  509 the model performs well
# Acuraccy of training model : 47.06033983787764
# Accuracy of testing model : 47.2830442008188
#
# -----------------------------------------
#
# At random state  512 the model performs well
# Acuraccy of training model : 46.98574691770797
# Accuracy of testing model : 47.48344023506872
#
# -----------------------------------------
#
# At random state  519 the model performs well
# Acuraccy of training model : 47.183334725454486
# Accuracy of testing model : 46.99944589300027
#
# -----------------------------------------
#
# At random state  520 the model performs well
# Acuraccy of training model : 47.027426092285616
# Accuracy of testing model : 47.39274045478934
#
# -----------------------------------------
#
# At random state  521 the model performs well
# Acuraccy of training model : 47.05685242401999
# Accuracy of testing model : 47.326127775497405
#
# -----------------------------------------
#
# At random state  522 the model performs well
# Acuraccy of training model : 47.153126734671524
# Accuracy of testing model : 47.042967949341715
#
# -----------------------------------------
#
# At random state  524 the model performs well
# Acuraccy of training model : 47.402333420308686
# Accuracy of testing model : 46.50653466957482
#
# -----------------------------------------
#
# At random state  525 the model performs well
# Acuraccy of training model : 47.3571103682
# Accuracy of testing model : 46.619575654537456
#
# -----------------------------------------
#
# At random state  528 the model performs well
# Acuraccy of training model : 47.21999554685846
# Accuracy of testing model : 46.92147028631286
#
# -----------------------------------------
#
# At random state  531 the model performs well
# Acuraccy of training model : 47.22038507005676
# Accuracy of testing model : 46.920990380820136
#
# -----------------------------------------
#
# At random state  533 the model performs well
# Acuraccy of training model : 47.1162798947939
# Accuracy of testing model : 47.167923583215114
#
# -----------------------------------------
#
# At random state  534 the model performs well
# Acuraccy of training model : 46.98815135834015
# Accuracy of testing model : 47.47418937641946
#
# -----------------------------------------
#
# At random state  535 the model performs well
# Acuraccy of training model : 47.10544668255184
# Accuracy of testing model : 47.15647682926335
#
# -----------------------------------------
#
# At random state  539 the model performs well
# Acuraccy of training model : 47.27720843235175
# Accuracy of testing model : 46.79279498480924
#
# -----------------------------------------
#
# At random state  540 the model performs well
# Acuraccy of training model : 47.04150379191948
# Accuracy of testing model : 47.31400992864765
#
# -----------------------------------------
#
# At random state  544 the model performs well
# Acuraccy of training model : 47.371579908608496
# Accuracy of testing model : 46.57653306897621
#
# -----------------------------------------
#
# At random state  549 the model performs well
# Acuraccy of training model : 47.224429348478004
# Accuracy of testing model : 46.892373347643044
#
# -----------------------------------------
#
# At random state  550 the model performs well
# Acuraccy of training model : 47.37460131208171
# Accuracy of testing model : 46.596640429439795
#
# -----------------------------------------
#
# At random state  552 the model performs well
# Acuraccy of training model : 47.23153704947441
# Accuracy of testing model : 46.89119136356307
#
# -----------------------------------------
#
# At random state  555 the model performs well
# Acuraccy of training model : 47.328787433418185
# Accuracy of testing model : 46.68881407743692
#
# -----------------------------------------
#
# At random state  556 the model performs well
# Acuraccy of training model : 47.20270899442092
# ...
# Accuracy of testing model : 47.18675366326535
#
# -----------------------------------------
#
# At random state  819 the model performs well
# Acuraccy of training model : 47.036728945183384
# Accuracy of testing model : 47.34266803302219
#
# -----------------------------------------
#
# At random state  820 the model performs well
# Acuraccy of training model : 47.21679995200483
# Accuracy of testing model : 46.90665256896628
#
# -----------------------------------------
#
# At random state  821 the model performs well
# Acuraccy of training model : 47.09756373892885
# Accuracy of testing model : 47.2143496823481
#
# -----------------------------------------
#
# At random state  822 the model performs well
# Acuraccy of training model : 47.236895155536665
# Accuracy of testing model : 46.87556410672493
#
# -----------------------------------------
#
# At random state  824 the model performs well
# Acuraccy of training model : 47.157860749004
# Accuracy of testing model : 47.04343568276694
#
# -----------------------------------------
#
# At random state  827 the model performs well
# Acuraccy of training model : 47.18347664419584
# Accuracy of testing model : 46.996099892866326
#
# -----------------------------------------
#
# At random state  829 the model performs well
# Acuraccy of training model : 47.28020624357383
# Accuracy of testing model : 46.70465373138843
#
# -----------------------------------------
#
# At random state  831 the model performs well
# Acuraccy of training model : 47.329998695351435
# Accuracy of testing model : 46.664713878749644
#
# -----------------------------------------
#
# At random state  832 the model performs well
# Acuraccy of training model : 47.312427311515684
# Accuracy of testing model : 46.718367360457755
#
# -----------------------------------------
#
# At random state  834 the model performs well
# Acuraccy of training model : 47.02301211250569
# Accuracy of testing model : 47.352509846521016
#
# -----------------------------------------
#
# At random state  840 the model performs well
# Acuraccy of training model : 47.35571981071184
# Accuracy of testing model : 46.561189284961614
#
# -----------------------------------------
#
# At random state  842 the model performs well
# Acuraccy of training model : 47.061200240266324
# Accuracy of testing model : 47.29112388268102
#
# -----------------------------------------
#
# At random state  843 the model performs well
# Acuraccy of training model : 47.14982752261388
# Accuracy of testing model : 47.03198527315693
#
# -----------------------------------------
#
# At random state  844 the model performs well
# Acuraccy of training model : 47.289007820475646
# Accuracy of testing model : 46.78201390100899
#
# -----------------------------------------
#
# At random state  845 the model performs well
# Acuraccy of training model : 47.076360386754445
# Accuracy of testing model : 47.27360438434266
#
# -----------------------------------------
#
# At random state  848 the model performs well
# Acuraccy of training model : 46.968247802719354
# Accuracy of testing model : 47.49839023427258
#
# -----------------------------------------
#
# At random state  851 the model performs well
# Acuraccy of training model : 47.20694523333806
# Accuracy of testing model : 46.89761948264232
#
# -----------------------------------------
#
# At random state  852 the model performs well
# Acuraccy of training model : 47.146862629191574
# Accuracy of testing model : 47.092562924546755
#
# -----------------------------------------
#
# At random state  854 the model performs well
# Acuraccy of training model : 47.190759690664706
# Accuracy of testing model : 46.970602608243986
#
# -----------------------------------------
#
# At random state  855 the model performs well
# Acuraccy of training model : 47.2805775610626
# Accuracy of testing model : 46.73870578459704
#
# -----------------------------------------
#
# At random state  856 the model performs well
# Acuraccy of training model : 47.364799957666015
# Accuracy of testing model : 46.608212878135234
#
# -----------------------------------------
#
# At random state  857 the model performs well
# Acuraccy of training model : 47.02971247120935
# Accuracy of testing model : 47.37270550221997
#
# -----------------------------------------
#
# At random state  858 the model performs well
# Acuraccy of training model : 46.97601328989896
# Accuracy of testing model : 47.4953418273443
#
# -----------------------------------------
#
# At random state  859 the model performs well
# Acuraccy of training model : 46.982563011849045
# Accuracy of testing model : 47.468851117312674
#
# -----------------------------------------
#
# At random state  860 the model performs well
# Acuraccy of training model : 47.274705210592906
# Accuracy of testing model : 46.76512839621571
#
# -----------------------------------------
#
# At random state  861 the model performs well
# Acuraccy of training model : 47.37146674345046
# Accuracy of testing model : 46.55241432107774
#
# -----------------------------------------
#
# At random state  864 the model performs well
# Acuraccy of training model : 47.18809023757862
# Accuracy of testing model : 46.984172634363254
#
# -----------------------------------------
#
# At random state  867 the model performs well
# Acuraccy of training model : 47.352514889993124
# Accuracy of testing model : 46.59959394363402
#
# -----------------------------------------
#
# At random state  868 the model performs well
# Acuraccy of training model : 47.13135061836816
# Accuracy of testing model : 47.14156076732782
#
# -----------------------------------------
#
# At random state  869 the model performs well
# Acuraccy of training model : 47.27887751317574
# Accuracy of testing model : 46.79945401455424
#
# -----------------------------------------
#
# At random state  873 the model performs well
# Acuraccy of training model : 46.96773768609841
# Accuracy of testing model : 47.47980344162184
#
# -----------------------------------------
#
# At random state  875 the model performs well
# Acuraccy of training model : 47.10471491724794
# Accuracy of testing model : 47.20558597119492
#
# -----------------------------------------
#
# At random state  877 the model performs well
# Acuraccy of training model : 46.99695220925649
# Accuracy of testing model : 47.40380163390008
#
# -----------------------------------------
#
# At random state  882 the model performs well
# Acuraccy of training model : 47.31083668716298
# Accuracy of testing model : 46.72747892784807
#
# -----------------------------------------
#
# At random state  883 the model performs well
# Acuraccy of training model : 47.166898240982725
# Accuracy of testing model : 47.03036271516915
#
# -----------------------------------------
#
# At random state  884 the model performs well
# Acuraccy of training model : 47.24073212926039
# Accuracy of testing model : 46.876528926396475
#
# -----------------------------------------
#
# At random state  888 the model performs well
# Acuraccy of training model : 47.286429327352984
# Accuracy of testing model : 46.75991095339129
#
# -----------------------------------------
#
# At random state  889 the model performs well
# Acuraccy of training model : 47.330624432463196
# Accuracy of testing model : 46.67139708095658
#
# -----------------------------------------
#
# At random state  891 the model performs well
# Acuraccy of training model : 46.98854381388028
# Accuracy of testing model : 47.420564058018776
#
# -----------------------------------------
#
# At random state  893 the model performs well
# Acuraccy of training model : 47.080578040337365
# Accuracy of testing model : 47.24476578827732
#
# -----------------------------------------
#
# At random state  898 the model performs well
# Acuraccy of training model : 47.380669198294015
# Accuracy of testing model : 46.5508659230747
#
# -----------------------------------------
#
# At random state  902 the model performs well
# Acuraccy of training model : 47.13497441529135
# Accuracy of testing model : 47.059561463405664
#
# -----------------------------------------
#
# At random state  904 the model performs well
# Acuraccy of training model : 47.28289701717819
# Accuracy of testing model : 46.74428578369996
#
# -----------------------------------------
#
# At random state  905 the model performs well
# Acuraccy of training model : 47.006074022339305
# Accuracy of testing model : 47.41964832786925
#
# -----------------------------------------
#
# At random state  906 the model performs well
# Acuraccy of training model : 47.17994018885605
# Accuracy of testing model : 46.98872463108589
#
# -----------------------------------------
#
# At random state  911 the model performs well
# Acuraccy of training model : 47.32042696158582
# Accuracy of testing model : 46.66402395347775
#
# -----------------------------------------
#
# At random state  919 the model performs well
# Acuraccy of training model : 47.37689507372291
# Accuracy of testing model : 46.54018715103857
#
# -----------------------------------------
#
# At random state  920 the model performs well
# Acuraccy of training model : 47.09681731724963
# Accuracy of testing model : 47.21444142145623
#
# -----------------------------------------
#
# At random state  921 the model performs well
# Acuraccy of training model : 47.167936586256666
# Accuracy of testing model : 47.00931631906394
#
# -----------------------------------------
#
# At random state  922 the model performs well
# Acuraccy of training model : 47.10808085911605
# Accuracy of testing model : 47.195805985563325
#
# -----------------------------------------
#
# At random state  923 the model performs well
# Acuraccy of training model : 47.09522349974847
# Accuracy of testing model : 47.202133613418106
#
# -----------------------------------------
#
# At random state  924 the model performs well
# Acuraccy of training model : 47.35560708478332
# Accuracy of testing model : 46.56358994056124
#
# -----------------------------------------
#
# At random state  925 the model performs well
# Acuraccy of training model : 47.073299740645055
# Accuracy of testing model : 47.23476054290507
#
# -----------------------------------------
#
# At random state  926 the model performs well
# Acuraccy of training model : 47.015938747029
# Accuracy of testing model : 47.41768773493508
#
# -----------------------------------------
#
# At random state  928 the model performs well
# Acuraccy of training model : 47.20199052093008
# Accuracy of testing model : 46.96985689930544
#
# -----------------------------------------
#
# At random state  930 the model performs well
# Acuraccy of training model : 47.080269559163455
# Accuracy of testing model : 47.24179768052984
#
# -----------------------------------------
#
# At random state  933 the model performs well
# Acuraccy of training model : 46.9968829883871
# Accuracy of testing model : 47.41850173079776
#
# -----------------------------------------
#
# At random state  935 the model performs well
# Acuraccy of training model : 47.120685380495196
# Accuracy of testing model : 47.14606900011753
#
# -----------------------------------------
#
# At random state  937 the model performs well
# Acuraccy of training model : 47.126815200917186
# Accuracy of testing model : 47.129741196383875
#
# -----------------------------------------
#
# At random state  938 the model performs well
# Acuraccy of training model : 47.00982514044468
# Accuracy of testing model : 47.37102677352142
#
# -----------------------------------------
#
# At random state  941 the model performs well
# Acuraccy of training model : 46.950713498697624
# Accuracy of testing model : 47.49183005236753
#
# -----------------------------------------
#
# At random state  946 the model performs well
# Acuraccy of training model : 47.26275039896196
# Accuracy of testing model : 46.788979327925176
#
# -----------------------------------------
#
# At random state  947 the model performs well
# Acuraccy of training model : 47.313841413696764
# Accuracy of testing model : 46.70380597857546
#
# -----------------------------------------
#
# At random state  951 the model performs well
# Acuraccy of training model : 47.39171626602051
# Accuracy of testing model : 46.53411810471799
#
# -----------------------------------------
#
# At random state  952 the model performs well
# Acuraccy of training model : 47.086799040982505
# Accuracy of testing model : 47.23939291039194
#
# -----------------------------------------
#
# At random state  953 the model performs well
# Acuraccy of training model : 47.28661330348306
# Accuracy of testing model : 46.7439368602375
#
# -----------------------------------------
#
# At random state  954 the model performs well
# Acuraccy of training model : 47.27947537560488
# Accuracy of testing model : 46.774052833445076
#
# -----------------------------------------
#
# At random state  955 the model performs well
# Acuraccy of training model : 47.11265331288682
# Accuracy of testing model : 47.14089346894509
#
# -----------------------------------------
#
# At random state  960 the model performs well
# Acuraccy of training model : 47.31789897971538
# Accuracy of testing model : 46.683905523587235
#
# -----------------------------------------
#
# At random state  962 the model performs well
# Acuraccy of training model : 47.31161639663053
# Accuracy of testing model : 46.65204682108018
#
# -----------------------------------------
#
# At random state  964 the model performs well
# Acuraccy of training model : 47.29689820322748
# Accuracy of testing model : 46.701440374622536
#
# -----------------------------------------
#
# At random state  967 the model performs well
# Acuraccy of training model : 47.12372278629812
# Accuracy of testing model : 47.15670845398895
#
# -----------------------------------------
#
# At random state  969 the model performs well
# Acuraccy of training model : 47.15475665709934
# Accuracy of testing model : 47.086562931995424
#
# -----------------------------------------
#
# At random state  970 the model performs well
# Acuraccy of training model : 47.185819678703986
# Accuracy of testing model : 47.021850679976914
#
# -----------------------------------------
#
# At random state  973 the model performs well
# Acuraccy of training model : 46.96734596131845
# Accuracy of testing model : 47.492103153163825
#
# -----------------------------------------
#
# At random state  974 the model performs well
# Acuraccy of training model : 47.3192713003194
# Accuracy of testing model : 46.69527299348083
#
# -----------------------------------------
#
# At random state  976 the model performs well
# Acuraccy of training model : 47.22686036129525
# Accuracy of testing model : 46.89933289299518
#
# -----------------------------------------
#
# At random state  981 the model performs well
# Acuraccy of training model : 47.342818937104894
# Accuracy of testing model : 46.58602316873236
#
# -----------------------------------------
#
# At random state  984 the model performs well
# Acuraccy of training model : 47.23675050083165
# Accuracy of testing model : 46.89434970501362
#
# -----------------------------------------
#
# At random state  985 the model performs well
# Acuraccy of training model : 47.342180167673476
# Accuracy of testing model : 46.62622353229443
#
# -----------------------------------------
#
# At random state  986 the model performs well
# Acuraccy of training model : 47.17984070902004
# Accuracy of testing model : 46.98062884801596
#
# -----------------------------------------
#
# At random state  987 the model performs well
# Acuraccy of training model : 47.38278044126842
# Accuracy of testing model : 46.51437706415844
#
# -----------------------------------------
#
# At random state  990 the model performs well
# Acuraccy of training model : 47.278620256959705
# Accuracy of testing model : 46.78335763561411
#
# -----------------------------------------
#
# At random state  992 the model performs well
# Acuraccy of training model : 47.30674127959562
# Accuracy of testing model : 46.70728852874013
#
# -----------------------------------------
#
# At random state  994 the model performs well
# Acuraccy of training model : 46.98530213928072
# Accuracy of testing model : 47.445832657229836
#
# -----------------------------------------
#
# At random state  997 the model performs well
# Acuraccy of training model : 46.99771065504872
# Accuracy of testing model : 47.431682415855924
#
# -----------------------------------------
#
# At random state  998 the model performs well
# Acuraccy of training model : 47.16128547688775
# Accuracy of testing model : 47.05921616593534
#
# -----------------------------------------

# %%
#traintestsplit
x_train,x_test,y_train,y_test = train_test_split (X_scaled2,Y, test_size=0.3, random_state = 224)

# %%
# Model Selection
def model_selection (algorithm, x_train,y_train,x_test,y_test):
    algorithm.fit(x_train,y_train)
    pred_train = algorithm.predict(x_train)
    pred_test = algorithm.predict(x_test)
    mse = mean_squared_error(y_test,pred_test)

    print (algorithm)
    print ("Acuraccy of training model :",r2_score(y_train,pred_train))
    print ("Accuracy of testing model :",r2_score(y_test,pred_test))
    print ("RMSE : ",sqrt(mse))
    print ("\n-----------------------------------------\n")

# %%
#Training Model
#Linear Regression
lr= LinearRegression()
model_selection(lr,x_train,y_train,x_test,y_test)


#Decision Tree
dtr = DecisionTreeRegressor()
model_selection(dtr,x_train,y_train,x_test,y_test)

#Random Forest 
rf= RandomForestRegressor()
model_selection(rf,x_train,y_train,x_test,y_test)

#Support Vector Regressor:
svr = SVR()
model_selection(svr,x_train,y_train,x_test,y_test)
# Out:
# LinearRegression()
# Acuraccy of training model : 0.4719138599475031
# Accuracy of testing model : 0.47000124859994563
# RMSE :  0.29403390496170473
#
# -----------------------------------------
#
# DecisionTreeRegressor()
# Acuraccy of training model : 1.0
# Accuracy of testing model : 0.5875249297275851
# RMSE :  0.25939335181404194
#
# -----------------------------------------
#
# RandomForestRegressor()
# Acuraccy of training model : 0.9732613301594615
# Accuracy of testing model : 0.806478809511189
# RMSE :  0.17767415225246375
#
# -----------------------------------------
#
# SVR()
# Acuraccy of training model : 0.6509623646346226
# Accuracy of testing model : 0.6423236221694733
# RMSE :  0.24154892990113658
#
# -----------------------------------------

# %%
# Hyperparameter Tuning:
parameters = {'n_estimators':(25,50,75,100),
    'max_features':['auto','sqrt','log2'],
    'max_depth': (8,12,15),
    'min_samples_leaf': (5,8,10),
    'min_samples_split':range(5,7,10)
    }

clf = GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print (clf.best_params_)
# Out:
# {'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 75}

# %%
rf1= RandomForestRegressor(n_estimators=100,max_features='auto', max_depth = 15, min_samples_leaf = 5, min_samples_split = 5)
model_selection(rf1,x_train,y_train,x_test,y_test)
# Out:
# RandomForestRegressor(max_depth=15, min_samples_leaf=5, min_samples_split=5)
# Acuraccy of training model : 0.8934778209178166
# Accuracy of testing model : 0.7827615264654952
# RMSE :  0.18824712825240567
#
# -----------------------------------------

# %%
# Saving Model
import pickle
filename= 'Avacdo_reg.pkl'
pickle.dump(rf,open(filename, 'wb'))

# %%
#Final Prediction
a= np.array(y_test)
predicted=np.array (rf.predict(x_test))
df = pd.DataFrame({"Orignal":a, "Predicted":predicted}, index = range(len(a)))
df
# Out:
#       Orignal  Predicted
# 0        0.99     0.9968
# 1        1.75     1.7174
# 2        1.21     1.4300
# 3        1.02     0.8755
# 4        2.43     2.3439
# ...       ...        ...
# 5330     1.69     1.4754
# 5331     1.59     1.7064
# 5332     2.06     2.0660
# 5333     0.96     1.0084
# 5334     1.93     1.6736
#
# [5335 rows x 2 columns]

# %%
sns.lmplot(x='Orignal',y='Predicted',data=df)

# %%
# Dividing data into feature and label
x= clf_data.drop(columns=['region'])
y= clf_data['region']

# %%
#Applying PowerTransformer
pt = PowerTransformer()
x_scaled = pd.DataFrame(pt.fit_transform(x), columns=x.columns)

# %%
x_scaled
# Out:
#        AveragePrice  Total Volume      4046      4225      4770  Total Bags  \
# 0         -0.117824     -0.075324 -0.657421  0.351430 -0.222566   -0.537507
# 1         -0.064330     -0.147497 -0.777179  0.269513 -0.175223   -0.498128
# 2         -1.298865      0.205556 -0.731776  0.649333  0.023923   -0.566369
# 3         -0.829026      0.019655 -0.632592  0.468799 -0.121164   -0.713068
# 4         -0.253635     -0.180674 -0.684504  0.262126 -0.110491   -0.686312
# ...             ...           ...       ...       ...       ...         ...
# 17646      0.639410     -0.678214 -0.462066 -0.926028 -1.228986   -0.340422
# 17647      0.826487     -0.771326 -0.618019 -0.670600 -1.228986   -0.509513
# 17648      1.184324     -0.775274 -0.617966 -0.778893  0.445710   -0.503366
# 17649      1.313296     -0.701797 -0.547011 -0.716371  0.445399   -0.434176
# 17650      0.615619     -0.667381 -0.359671 -0.791650  0.157768   -0.393236
#
#        Small Bags  Large Bags  XLarge Bags      type      year
# 0       -0.347421   -0.781153    -0.677919 -1.019047 -1.210647
# 1       -0.311322   -0.771198    -0.677919 -1.019047 -1.210647
# 2       -0.374453   -0.758523    -0.677919 -1.019047 -1.210647
# 3       -0.510991   -0.699123    -0.677919 -1.019047 -1.210647
# 4       -0.490534   -0.607027    -0.677919 -1.019047 -1.210647
# ...           ...         ...          ...       ...       ...
# 17646   -0.175753   -0.412401    -0.677919  0.981309  1.978707
# 17647   -0.331971   -0.484991    -0.677919  0.981309  1.978707
# 17648   -0.313756   -0.950743    -0.677919  0.981309  1.978707
# 17649   -0.250408   -0.916068    -0.677919  0.981309  1.978707
# 17650   -0.211755   -1.048116    -0.677919  0.981309  1.978707
#
# [17651 rows x 11 columns]

# %%
x_scaled.skew()
# Out:
# AveragePrice    0.000464
# Total Volume   -0.008642
# 4046           -0.039282
# 4225           -0.044675
# 4770            0.024168
# Total Bags     -0.022204
# Small Bags     -0.024405
# Large Bags     -0.110913
# XLarge Bags     0.853758
# type           -0.037741
# year            0.227731
# dtype: float64

# %%
#Using VIF to check for muliticolinearity:
from statsmodels.stats.outliers_influence import variance_inflation_factor
Vif= pd.DataFrame()
Vif['vif']=[variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]
Vif['feature']= x_scaled.columns
Vif
# Out:
#           vif       feature
# 0    2.127152  AveragePrice
# 1   54.863391  Total Volume
# 2    6.905481          4046
# 3   12.362805          4225
# 4    3.941440          4770
# 5   35.756710    Total Bags
# 6   17.333635    Small Bags
# 7    3.472647    Large Bags
# 8    2.039068   XLarge Bags
# 9    4.115674          type
# 10   1.407651          year

# %%
x_scaled=x_scaled.drop(columns=['Total Volume','Total Bags'])

# %%
#Using VIF to check for muliticolinearity:
from statsmodels.stats.outliers_influence import variance_inflation_factor
Vif1= pd.DataFrame()
Vif1['vif']=[variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]
Vif1['feature']= x_scaled.columns
Vif1
# Out:
#         vif       feature
# 0  1.913817  AveragePrice
# 1  3.602702          4046
# 2  4.314199          4225
# 3  3.930990          4770
# 4  4.119981    Small Bags
# 5  2.038690    Large Bags
# 6  2.027128   XLarge Bags
# 7  3.961605          type
# 8  1.355953          year

# %%
plt.figure(figsize=(20,8))
sns.countplot(y)
plt.show()

# %%
#traintestsplit
lg = LogisticRegression()
for i in range(300,500):
    x_train,x_test,y_train,y_test = train_test_split (x_scaled,y, test_size=0.3, random_state = i)
    lg.fit(x_train,y_train)
    pred_train = lg.predict(x_train)
    pred_test = lg.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100)==round(accuracy_score(y_test,pred_test)*100):
        print ("At random state ",i,"the model performs well")
        print ("Acuraccy of training model :",accuracy_score(y_train,pred_train)*100)
        print ("Accuracy of testing model :",accuracy_score(y_test,pred_test)*100)
        print ("\n-----------------------------------------\n")
# Out:
# At random state  303 the model performs well
# Acuraccy of training model : 50.15783083771752
# Accuracy of testing model : 50.283232628398785
#
# -----------------------------------------
#
# At random state  311 the model performs well
# Acuraccy of training model : 50.02832861189802
# Accuracy of testing model : 49.52794561933535
#
# -----------------------------------------
#
# At random state  314 the model performs well
# Acuraccy of training model : 50.04451639012546
# Accuracy of testing model : 49.8678247734139
#
# -----------------------------------------
#
# At random state  315 the model performs well
# Acuraccy of training model : 50.08498583569405
# Accuracy of testing model : 50.41540785498489
#
# -----------------------------------------
#
# At random state  316 the model performs well
# Acuraccy of training model : 50.45730473492513
# Accuracy of testing model : 49.67900302114804
#
# -----------------------------------------
#
# At random state  318 the model performs well
# Acuraccy of training model : 50.1902063941724
# Accuracy of testing model : 49.8678247734139
#
# -----------------------------------------
#
# At random state  322 the model performs well
# Acuraccy of training model : 50.33589639821935
# Accuracy of testing model : 49.58459214501511
#
# -----------------------------------------
#
# At random state  323 the model performs well
# Acuraccy of training model : 50.433023067583974
# Accuracy of testing model : 50.2643504531722
#
# -----------------------------------------
#
# At random state  331 the model performs well
# Acuraccy of training model : 50.47349251315257
# Accuracy of testing model : 49.660120845921455
#
# -----------------------------------------
#
# At random state  344 the model performs well
# Acuraccy of training model : 50.036422501011735
# Accuracy of testing model : 50.43429003021148
#
# -----------------------------------------
#
# At random state  349 the model performs well
# Acuraccy of training model : 49.801699716713884
# Accuracy of testing model : 50.30211480362537
#
# -----------------------------------------
#
# At random state  350 the model performs well
# Acuraccy of training model : 50.45730473492513
# Accuracy of testing model : 49.52794561933535
#
# -----------------------------------------
#
# At random state  355 the model performs well
# Acuraccy of training model : 50.27114528530959
# Accuracy of testing model : 49.77341389728097
#
# -----------------------------------------
#
# At random state  357 the model performs well
# Acuraccy of training model : 50.18211250505868
# Accuracy of testing model : 49.660120845921455
#
# -----------------------------------------
#
# At random state  367 the model performs well
# Acuraccy of training model : 50.33589639821935
# Accuracy of testing model : 50.2643504531722
#
# -----------------------------------------
#
# At random state  374 the model performs well
# Acuraccy of training model : 50.24686361796843
# Accuracy of testing model : 49.67900302114804
#
# -----------------------------------------
#
# At random state  376 the model performs well
# Acuraccy of training model : 50.33589639821935
# Accuracy of testing model : 49.848942598187314
#
# -----------------------------------------
#
# At random state  380 the model performs well
# Acuraccy of training model : 50.20639417239984
# Accuracy of testing model : 49.8678247734139
#
# -----------------------------------------
#
# At random state  386 the model performs well
# Acuraccy of training model : 50.20639417239984
# Accuracy of testing model : 49.88670694864049
#
# -----------------------------------------
#
# At random state  388 the model performs well
# Acuraccy of training model : 50.49777418049373
# Accuracy of testing model : 50.41540785498489
#
# -----------------------------------------
#
# At random state  393 the model performs well
# Acuraccy of training model : 50.13354917037637
# Accuracy of testing model : 50.20770392749244
#
# -----------------------------------------
#
# At random state  394 the model performs well
# Acuraccy of training model : 50.37636584378794
# Accuracy of testing model : 49.56570996978852
#
# -----------------------------------------
#
# At random state  396 the model performs well
# Acuraccy of training model : 50.20639417239984
# Accuracy of testing model : 50.16993957703928
#
# -----------------------------------------
#
# At random state  400 the model performs well
# Acuraccy of training model : 50.48158640226629
# Accuracy of testing model : 49.50906344410876
#
# -----------------------------------------
#
# At random state  401 the model performs well
# Acuraccy of training model : 50.076891946580325
# Accuracy of testing model : 50.07552870090635
#
# -----------------------------------------
#
# At random state  418 the model performs well
# Acuraccy of training model : 49.89073249696479
# Accuracy of testing model : 49.94335347432024
#
# -----------------------------------------
#
# At random state  419 the model performs well
# Acuraccy of training model : 50.14973694860381
# Accuracy of testing model : 50.01888217522659
#
# -----------------------------------------
#
# At random state  420 the model performs well
# Acuraccy of training model : 50.23067583974099
# Accuracy of testing model : 50.09441087613293
#
# -----------------------------------------
#
# At random state  426 the model performs well
# Acuraccy of training model : 50.18211250505868
# Accuracy of testing model : 49.660120845921455
#
# -----------------------------------------
#
# At random state  428 the model performs well
# Acuraccy of training model : 50.35208417644679
# Accuracy of testing model : 49.8678247734139
#
# -----------------------------------------
#
# At random state  446 the model performs well
# Acuraccy of training model : 50.27923917442331
# Accuracy of testing model : 50.2643504531722
#
# -----------------------------------------
#
# At random state  456 the model performs well
# Acuraccy of training model : 49.86645082962363
# Accuracy of testing model : 49.603474320241695
#
# -----------------------------------------
#
# At random state  458 the model performs well
# Acuraccy of training model : 50.26305139619587
# Accuracy of testing model : 50.0
#
# -----------------------------------------
#
# At random state  467 the model performs well
# Acuraccy of training model : 49.90692027519223
# Accuracy of testing model : 50.35876132930513
#
# -----------------------------------------
#
# At random state  473 the model performs well
# Acuraccy of training model : 50.11736139214893
# Accuracy of testing model : 49.96223564954683
#
# -----------------------------------------
#
# At random state  475 the model performs well
# Acuraccy of training model : 50.35208417644679
# Accuracy of testing model : 49.56570996978852
#
# -----------------------------------------
#
# At random state  477 the model performs well
# Acuraccy of training model : 50.26305139619587
# Accuracy of testing model : 50.03776435045317
#
# -----------------------------------------
#
# At random state  481 the model performs well
# Acuraccy of training model : 50.13354917037637
# Accuracy of testing model : 50.453172205438065
#
# -----------------------------------------
#
# At random state  483 the model performs well
# Acuraccy of training model : 49.79360582760016
# Accuracy of testing model : 49.52794561933535
#
# -----------------------------------------
#
# At random state  484 the model performs well
# Acuraccy of training model : 50.076891946580325
# Accuracy of testing model : 50.226586102719025
#
# -----------------------------------------
#
# At random state  487 the model performs well
# Acuraccy of training model : 50.29542695265074
# Accuracy of testing model : 50.15105740181269
#
# -----------------------------------------
#
# At random state  495 the model performs well
# Acuraccy of training model : 50.02832861189802
# Accuracy of testing model : 50.0
#
# -----------------------------------------

# %%
#traintestsplit
x_train,x_test,y_train,y_test = train_test_split (x_scaled,y, test_size=0.3, random_state = 446)

# %%
# Model Selection
def model_selection (algorithm, x_train,y_train,x_test,y_test):
    algorithm.fit(x_train,y_train)
    pred_train = algorithm.predict(x_train)
    pred_test = algorithm.predict(x_test)
    
    print(algorithm)
    print ("Acuraccy of training model :",accuracy_score(y_train,pred_train))
    print ("Accuracy of testing model :",accuracy_score(y_test,pred_test))
    print ("Confusion Matrix \n",confusion_matrix(y_test,pred_test))
    print ("\n-----------------------------------------\n")

# %%
#Logistic Regression
lr= LogisticRegression()
model_selection(lr,x_train,y_train,x_test,y_test)

#KNN
knn= KNeighborsClassifier()
model_selection(knn,x_train,y_train,x_test,y_test)

#Decision Tree
dtc = DecisionTreeClassifier()
model_selection(dtc,x_train,y_train,x_test,y_test)

#Random Forest 
rfc= RandomForestClassifier()
model_selection(rfc,x_train,y_train,x_test,y_test)
# Out:
# LogisticRegression()
# Acuraccy of training model : 0.5027923917442331
# Accuracy of testing model : 0.502643504531722
# Confusion Matrix
#  [[66  0  0 ...  0  0  0]
#  [ 0 48  0 ...  0  0  0]
#  [ 0  0 60 ...  0  0  6]
#  ...
#  [ 0  0  0 ... 41  1  0]
#  [ 0  0  0 ...  0 69  0]
#  [ 0  6  3 ...  0  0 12]]
#
# -----------------------------------------
#
# KNeighborsClassifier()
# Acuraccy of training model : 0.8997167138810198
# Accuracy of testing model : 0.8259063444108762
# Confusion Matrix
#  [[103   0   0 ...   0   0   0]
#  [  0  76   0 ...   0   0   2]
#  [  0   0 103 ...   0   0   0]
#  ...
#  [  0   0   0 ...  42   0   0]
#  [  0   0   0 ...   0  79   0]
#  [  0   0   2 ...   0   0  78]]
#
# -----------------------------------------
#
# DecisionTreeClassifier()
# Acuraccy of training model : 1.0
# Accuracy of testing model : 0.793429003021148
# Confusion Matrix
#  [[81  0  0 ...  0  0  0]
#  [ 0 83  0 ...  0  0  1]
#  [ 0  0 98 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 42  0  0]
#  [ 0  1  0 ...  0 77  0]
#  [ 0  0  1 ...  0  0 63]]
#
# -----------------------------------------
#
# RandomForestClassifier()
# Acuraccy of training model : 1.0
# Accuracy of testing model : 0.907666163141994
# Confusion Matrix
#  [[102   0   0 ...   0   0   0]
#  [  0  93   0 ...   0   0   0]
#  [  0   0 108 ...   0   0   0]
#  ...
#  [  0   0   0 ...  42   0   0]
#  [  0   0   0 ...   0  82   0]
#  [  0   0   0 ...   0   0  80]]
#
# -----------------------------------------

# %%
# Hyperparameter Tuning :

#Decision Tree
parameters = {'criterion':['gini','entropy'],
    'max_depth': range(10,12),
    'min_samples_leaf': range(2,5),
    'min_samples_split':range(3,6)
    }

clf = GridSearchCV(dtc,parameters)
clf.fit(x_train,y_train)
print ("DecisionTree: \n",clf.best_params_)

#KNN
parameters = {'algorithm':['kd-tree','brute'],
    'leaf_size': range(3,7),
    'n_neighbors': range(3,10)
    }

clf = GridSearchCV(knn,parameters)
clf.fit(x_train,y_train)
print ("KNN: \n",clf.best_params_)

#RandomForests
parameters = {'criterion':['gini','entropy'],
    'max_depth': range(8,12),
    'min_samples_leaf': range(3,5,7),
    'min_samples_split':range(3,6),
    'n_estimators':(50,75,100)
    }

clf = GridSearchCV(rfc,parameters)
clf.fit(x_train,y_train)
print ("RandomForests: \n",clf.best_params_)
# Out:
# DecisionTree:
#  {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 3, 'min_samples_split': 3}
# KNN:
#  {'algorithm': 'brute', 'leaf_size': 3, 'n_neighbors': 3}
# RandomForests:
#  {'criterion': 'entropy', 'max_depth': 11, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 100}

# %%
#KNN
knn1= KNeighborsClassifier(algorithm='brute',leaf_size=3,n_neighbors=3)
model_selection(knn1,x_train,y_train,x_test,y_test)

#Decision Tree
dtc1 = DecisionTreeClassifier(criterion='entropy',max_depth=11,min_samples_leaf=2,min_samples_split=4)
model_selection(dtc1,x_train,y_train,x_test,y_test)

#Random Forest 
rfc1= RandomForestClassifier(criterion='entropy',max_depth=11,min_samples_leaf=3,min_samples_split=4,n_estimators=100)
model_selection(rfc1,x_train,y_train,x_test,y_test)
# Out:
# KNeighborsClassifier(algorithm='brute', leaf_size=3, n_neighbors=3)
# Acuraccy of training model : 0.9312828814245245
# Accuracy of testing model : 0.8462990936555891
# Confusion Matrix
#  [[105   0   0 ...   0   0   0]
#  [  0  86   0 ...   0   0   1]
#  [  0   0 105 ...   0   0   0]
#  ...
#  [  0   0   0 ...  42   0   0]
#  [  0   0   0 ...   0  80   0]
#  [  0   0   0 ...   0   0  80]]
#
# -----------------------------------------
#
# DecisionTreeClassifier(criterion='entropy', max_depth=11, min_samples_leaf=2,
#                        min_samples_split=4)
# Acuraccy of training model : 0.8436260623229461
# Accuracy of testing model : 0.7439577039274925
# Confusion Matrix
#  [[91  0  0 ...  0  0  0]
#  [ 0 71  0 ...  0  0  4]
#  [ 0  0 98 ...  0  0  3]
#  ...
#  [ 0  0  0 ... 40  0  0]
#  [ 0  0  0 ...  0 79  0]
#  [ 0  2  4 ...  0  0 66]]
#
# -----------------------------------------
#
# RandomForestClassifier(criterion='entropy', max_depth=11, min_samples_leaf=3,
#                        min_samples_split=4)
# Acuraccy of training model : 0.9559692432213679
# Accuracy of testing model : 0.8733006042296072
# Confusion Matrix
#  [[102   0   0 ...   0   0   0]
#  [  0  89   0 ...   0   0   0]
#  [  0   0 107 ...   0   0   0]
#  ...
#  [  0   0   0 ...  42   0   0]
#  [  0   0   0 ...   0  82   0]
#  [  0   0   1 ...   0   0  72]]
#
# -----------------------------------------

# %%
# Saving Model
import pickle
filename= 'Avacado_clf.pkl'
pickle.dump(rfc1,open(filename, 'wb'))

# %%
#Final Prediction
a= L_encoder.inverse_transform(np.array(y_test))
predicted=L_encoder.inverse_transform(np.array (rfc1.predict(x_test)))
df1 = pd.DataFrame({"Orignal":a, "Predicted":predicted}, index = range(len(a)))
df1
# Out:
#                   Orignal            Predicted
# 0                LasVegas        SouthCarolina
# 1                Columbus             Columbus
# 2              GreatLakes           GreatLakes
# 3     BaltimoreWashington  BaltimoreWashington
# 4               Charlotte            Charlotte
# ...                   ...                  ...
# 5291           LosAngeles           LosAngeles
# 5292            Northeast            Southeast
# 5293  HartfordSpringfield  HartfordSpringfield
# 5294              StLouis              StLouis
# 5295                Tampa                Tampa
#
# [5296 rows x 2 columns]
