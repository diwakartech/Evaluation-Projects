# %% [markdown]
# # GLOBAL POWER PLANT DATABASE PROJECT |

# %% [markdown]
# ### IMPORTING NECESSARY LIBRARIES-

# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ### LOAD THE DATASET -

# %%
gpp = pd.read_csv("C:\\Users\\diwak\\Downloads\\database_IND.csv")
pd.set_option('display.max_columns',None)
gpp.head(10)         # head()method will show the top 5 rows and columns
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
# 5     IND        India              AKRIMOTA LIG  IND0000003        250.0
# 6     IND        India                    ALIYAR  IND0000004         60.0
# 7     IND        India           ALLAIN DUHANGAN  IND0000005        192.0
# 8     IND        India               ALMATTI DAM  IND0000006        290.0
# 9     IND        India               AMAR KANTAK  IND0000007        210.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  other_fuel3  \
# 0   28.1839    73.2407        Solar         NaN         NaN          NaN
# ...

# %% [markdown]
# - The Global Power Plant dataset contains 27 columns where the data contains a blend of categorical and  numerical data with many missing values.

# %% [markdown]
# ### DATA EXPLORATION -

# %%
# Checking the shape of the dataset-

gpp.shape
print("There are {:,} rows ".format(gpp.shape[0]) + "and {} columns in our data".format(gpp.shape[1]))
# Out:
# There are 907 rows and 27 columns in our data

# %%
# checking the names of all the columns 

gpp.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_gwh_2019', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %% [markdown]
# #### These are the names of all the 27 columns present in the dataset.
#
# - country (text): 3 character country code corresponding to the ISO 3166-1 alpha-3 specification
# - country_long (text): longer form of the country designation
# - name (text): name or title of the power plant, generally in Romanized form
# - gppd_idnr (text): 10 or 12 character identifier for the power plant
# - capacity_mw (number): electrical generating capacity in megawatts
# - latitude (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
# - longitude (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
# - primary_fuel (text): energy source used in primary electricity generation or export
# - other_fuel1 (text): energy source used in electricity generation or export
# - other_fuel2 (text): energy source used in electricity generation or export
# - other_fuel3 (text): energy source used in electricity generation or export
# - commissioning_year (number): year of plant operation, weighted by unit-capacity when data is available
# - owner (text): majority shareholder of the power plant, generally in Romanized form
# - source (text): entity reporting the data; could be an organization, report, or document, generally in Romanized form
# - url (text): web document corresponding to the source field
# - geolocation_source (text): attribution for geolocation information
# - wepp_id (text): a reference to a unique plant identifier in the widely-used PLATTS-WEPP database.
# - year_of_capacity_data (number): year the capacity information was reported
# - generation_gwh_2014 (number): electricity generation in gigawatt-hours reported for the year 2014
# - generation_gwh_2015 (number): electricity generation in gigawatt-hours reported for the year 2015
# - generation_gwh_2017 (number): electricity generation in gigawatt-hours reported for the year 2017
# - generation_gwh_2018 (number): electricity generation in gigawatt-hours reported for the year 2018
# - generation_gwh_2019 (number): electricity generation in gigawatt-hours reported for the year 2019
# - generation_data_source (text): attribution for the reported generation information
# - estimated_generation_gwh_2013 (number): estimated electricity generation in gigawatt-hours for the year 2013
# - estimated_generation_gwh_2014 (number): estimated electricity generation in gigawatt-hours for the year 2014
# - estimated_generation_gwh_2015 (number): estimated electricity generation in gigawatt-hours for the year 2015
# - estimated_generation_gwh_2016 (number): estimated electricity generation in gigawatt-hours for the year 2016
# - estimated_generation_gwh_2017 (number): estimated electricity generation in gigawatt-hours for the year 2017
# - estimated_generation_note_2013 (text): label of the model/method used to estimate generation for the year 2013
# - estimated_generation_note_2014 (text): label of the model/method used to estimate generation for the year 2014
# - estimated_generation_note_2015 (text): label of the model/method used to estimate generation for the year 2015
# - estimated_generation_note_2016 (text): label of the model/method used to estimate generation for the year 2016
# - estimated_generation_note_2017 (text): label of the model/method used to estimate generation for the year 2017

# %%
# checking the datatypes of all the columns 

gpp.dtypes
# Out:
# country                      object
# country_long                 object
# name                         object
# gppd_idnr                    object
# capacity_mw                 float64
# latitude                    float64
# longitude                   float64
# primary_fuel                 object
# other_fuel1                  object
# other_fuel2                  object
# other_fuel3                 float64
# commissioning_year          float64
# owner                        object
# source                       object
# url                          object
# geolocation_source           object
# wepp_id                     float64
# year_of_capacity_data       float64
# generation_gwh_2013         float64
# generation_gwh_2014         float64
# generation_gwh_2015         float64
# generation_gwh_2016         float64
# generation_gwh_2017         float64
# generation_gwh_2018         float64
# generation_gwh_2019         float64
# generation_data_source       object
# ...

# %% [markdown]
# - There is float and object type data in the columns of the dataset.
#
# #### Categorical Column-
# `country,country_long,name,gppd_idnr,primary_fuel,other_fuel1,other_fuel2,owner,source,url,geolocation_source,
# generation_data_source.`
#
# #### Continuous Columns-
# `capacity_mw,latitude,longitude,other_fuel3,commissioning_year,wepp_id,year_of_capacity_data,generation_gwh_2013,
# generation_gwh_2014,generation_gwh_2015,generation_gwh_2016,generation_gwh_2017,estimated_generation_gwh.`

# %%
# Checking the info of the features in the dataset-

gpp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    object
# ...

# %% [markdown]
# #### KEY OBSERVATIONS -
#
# - There are 907 entries in our dataset with 27 attributes .
# - All of the features in this dataset are in float and object datatypes including our target variables where 'primary_fuel' is object whereas,'capacity_mw' is float.
# - The second column give us an idea about how big the dataset and how many non-null values are there for each field.
# - Now that we have got a glimpse of the dataset, we know that it does have multiple null values present in our dataset.
# - The total memory usage is 191.4+ KB

# %% [markdown]
# ### STATISTICAL SUMMARY-

# %%
gpp.describe()
# Out:
#        capacity_mw    latitude   longitude  other_fuel3  commissioning_year  \
# count   907.000000  861.000000  861.000000          0.0          527.000000
# mean    326.223755   21.197918   77.464907          NaN         1997.091082
# std     590.085456    6.239612    4.939316          NaN           17.082868
# min       0.000000    8.168900   68.644700          NaN         1927.000000
# 25%      16.725000   16.773900   74.256200          NaN         1988.000000
# 50%      59.200000   21.780000   76.719500          NaN         2001.000000
# 75%     385.250000   25.512400   79.440800          NaN         2012.000000
# max    4760.000000   34.649000   95.408000          NaN         2018.000000
#
#        wepp_id  year_of_capacity_data  generation_gwh_2013  \
# count      0.0                  519.0                  0.0
# mean       NaN                 2019.0                  NaN
# std        NaN                    0.0                  NaN
# ...

# %% [markdown]
# ### KEY OBSERVATIONS -
# - As we can see that only 'capacity_mw' column is having 907 count values ,other than that all the other columns has discrete as well as continuous data with missing values.
# - Mean is greater than Median in'capacity_mw','longtude','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017' and 'generation_gwh_2018' which indicates positively skewed data(right sided) .
# - Also, there is vast difference between 75th % and max values which is suggestive of presence of outliers.

# %% [markdown]
# ### CHECKING THE MISSING VALUES IN THE DATASET.

# %%
plt.figure(figsize=[12,8])
sns.heatmap(gpp.isnull())
print(gpp.isnull().sum())
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %% [markdown]
# #### KEY OBSERVATIONS -
#
# - There are huge number of missing values present in our dataset.
# - The columns :
#      'latitude', 'longitude', 'other_fuel1', 'other_fuel2','other_fuel3', 'commissioning_year','owner','geolocation_source','wepp_id','year_of_capacity_data', ''generation_gwh_2013','generation_gwh_2014','generation_gwh_2015', 'generation_gwh_2016',
#   'generation_gwh_2017', 'generation_gwh_2018', 'generation_gwh_2019','generation_data_source','estimated_generation_gwh'  are having null values in the data.So, we can drop those unnecessary columns.

# %% [markdown]
# ### CHECKING FOR UNIQUE ELEMENTS -

# %%
gpp.nunique()
# Out:
# country                       1
# country_long                  1
# name                        907
# gppd_idnr                   907
# capacity_mw                 361
# latitude                    836
# longitude                   827
# primary_fuel                  8
# other_fuel1                   3
# other_fuel2                   1
# other_fuel3                   0
# commissioning_year           73
# owner                       280
# source                      191
# url                         304
# geolocation_source            3
# wepp_id                       0
# year_of_capacity_data         1
# generation_gwh_2013           0
# generation_gwh_2014         371
# generation_gwh_2015         396
# generation_gwh_2016         403
# generation_gwh_2017         408
# generation_gwh_2018         410
# generation_gwh_2019           0
# generation_data_source        1
# estimated_generation_gwh      0
# dtype: int64

# %%
#checking the value count for each columns

for col in gpp.columns:   
    print('-' * 50 + col + '-' * 50 , end=' - ')
    display(gpp[col].value_counts().head())
# Out:
# --------------------------------------------------country-------------------------------------------------- -
# IND    907
# Name: country, dtype: int64
# --------------------------------------------------country_long-------------------------------------------------- -
# India    907
# Name: country_long, dtype: int64
# --------------------------------------------------name-------------------------------------------------- -
# ACME Solar Tower       1
# RAICHUR                1
# PRYAGRAJ (BARA) TPP    1
# PULICHINTALA           1
# PUNE MILL              1
# Name: name, dtype: int64
# --------------------------------------------------gppd_idnr-------------------------------------------------- -
# WRI1020239    1
# IND0000356    1
# IND0000346    1
# IND0000523    1
# WRI1019978    1
# Name: gppd_idnr, dtype: int64
# --------------------------------------------------capacity_mw-------------------------------------------------- -
# 5.0       39
# 10.0      22
# 600.0     20
# ...

# %% [markdown]
# ### KEY OBSERVATIONS-
#
# - The columns named 'country' and 'country_long' provides same details and are not necessary as there is only one category.
# - 'other_fuel2','other_fuel3','generation_gwh_2019 ','wepp_id ','generation_gwh_2013' and 'estimated_generation_gwh' are not necessary as there is no values present in the variable.
# - The columns like 'name','gppd_idnr','owner','source','url' and 'geolocation_source' are also not need as it only contact general information with missing values .

# %%
print('Minimum',gpp['capacity_mw'].min())
print('Maximum',gpp['capacity_mw'].max())
# Out:
# Minimum 0.0
# Maximum 4760.0

# %% [markdown]
# ### DROPPING THESE UNNECESSARY COLUMNS -

# %%
dropped_cols = ['country','country_long','name','gppd_idnr','owner','source','url','geolocation_source','generation_data_source','other_fuel3','wepp_id','generation_gwh_2013','generation_gwh_2019','estimated_generation_gwh']

gpp.drop(dropped_cols,axis = 1,inplace = True)
gpp.shape
# Out:
# (907, 13)

# %%
# Re-checking for null values 

gpp.isna().sum()
# Out:
# capacity_mw                0
# latitude                  46
# longitude                 46
# primary_fuel               0
# other_fuel1              709
# other_fuel2              906
# commissioning_year       380
# year_of_capacity_data    388
# generation_gwh_2014      509
# generation_gwh_2015      485
# generation_gwh_2016      473
# generation_gwh_2017      467
# generation_gwh_2018      459
# dtype: int64

# %% [markdown]
# #### KEY OBSERVATIONS
#
# - We can see that still most of the columns contains null/missing values ,except the target variables -'capacity_mw' and 'primary_fuel'.
# - Columns like 'other_fuel1' and 'other_fuel2' contains null values and are energy source which is used in generating electricity or export.Thereby, we can replace them with mode values without losing much data .

# %%
# For categorical columns replacing the missing values with mode-

gpp['other_fuel1'].fillna(gpp['other_fuel1'].mode()[0], inplace=True)
gpp['other_fuel2'].fillna(gpp['other_fuel2'].mode()[0], inplace=True)

# %%
# For numerical /continuous columns replacing the missing values with mean-

for i in gpp.columns:
    if gpp[i].dtypes =='float64':
        gpp[i] = gpp[i].fillna(np.mean(gpp[i]))

# %%
plt.figure(figsize=[8,6])
sns.heatmap(gpp.isnull())
print(gpp.isnull().sum())
# Out:
# capacity_mw              0
# latitude                 0
# longitude                0
# primary_fuel             0
# other_fuel1              0
# other_fuel2              0
# commissioning_year       0
# year_of_capacity_data    0
# generation_gwh_2014      0
# generation_gwh_2015      0
# generation_gwh_2016      0
# generation_gwh_2017      0
# generation_gwh_2018      0
# dtype: int64

# %% [markdown]
# - Finally , removed all the missing values from the dataset.

# %% [markdown]
# ### DATA VISUALIZATION

# %% [markdown]
# #### 1) UNIVARIATE ANALYSIS -

# %%
# Taking all the continuous data into one single variable -

features=gpp[['latitude','longitude','capacity_mw','commissioning_year','year_of_capacity_data','generation_gwh_2014',
              'generation_gwh_2015','generation_gwh_2016','generation_gwh_2017','generation_gwh_2018']]

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnum=1
for col in features:
    if plotnum<=15:
        plt.subplot(3,4,plotnum)
        sns.distplot(features[col],color='darkred')
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### KEY OBSERVATIONS -
# - 'Latitude' column is normally distributed.
# - 'Longitude' column is sightly skewed towards right.
# - Most of the power plants were commissioned between 1987 - 2002.
# -'capacity_mw','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017' and 'generation_gwh_2018' are skewed toward right.

# %% [markdown]
# ### VISUALISING BOTH THE DEPENDENT VARIABLE SEPERATELY-

# %%
#Visualising dependent variables -

plt.figure(figsize=(10,5))
sns.distplot(gpp.capacity_mw,kde=True,color='black')
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='Density'>

# %% [markdown]
# - Most of the data in column 'capacity_mw' is lying between the range 0 to 1000 and is right skewed .

# %%
# Visualising other dependent variable 'Primary_fuel' using countplot-

plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
gpp['primary_fuel'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(gpp['primary_fuel'])
gpp['primary_fuel'].value_counts()
# Out:
# Coal       258
# Hydro      251
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         20
# Nuclear      9
# Name: primary_fuel, dtype: int64

# %% [markdown]
# - There are total 8 different categories of primary fuels .
# - Those are solar, coal, wind, gas, hydro, biomass, oil and nuclear .
# - As noticed that majority coal(28.5%) and hydro(27.5%) are the key powerplants used in genearting electricity globally, while other thermal plants such as gas ,biomass,oil, and nuclear were the least used .
# - 'coal' and ' Hydro' contributed 258 and 251 each respectively.

# %%
plt.figure(figsize=(15,8))
plt.subplot(1,2,1)
gpp['other_fuel1'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(gpp['other_fuel1'],color='crimson')
gpp['other_fuel1'].value_counts()
# Out:
# Oil             904
# Gas               2
# Cogeneration      1
# Name: other_fuel1, dtype: int64

# %% [markdown]
# - From the above observations,other_fuel1 is having 3 categories - oil, Cogeneration and Gas.Out of which oil counts highest i.e 99.7%.

# %%
sns.countplot(gpp['other_fuel2'],color='indigo')
gpp['other_fuel2'].value_counts()
# Out:
# Oil    907
# Name: other_fuel2, dtype: int64

# %% [markdown]
# - From the above observations,other_fuel2 contains single value that is oil.

# %% [markdown]
# ### BIVARIATE ANALYSIS-

# %%
# Visualising latitude and longitude in the given data -

plt.figure(figsize=(10,8))
sns.scatterplot('longitude','latitude',data = gpp)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# - This shows that the global power plants are located all over the country

# %%
#Visualising both the dependent varibale togther -

plt.figure(figsize=(15,10))
sns.swarmplot('capacity_mw','primary_fuel', data = gpp)
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='primary_fuel'>

# %% [markdown]
# ### KEY OBSERVATIONS -
# - Most of the power plants use coal as `primary fuel` with much having `igher capacity`.
# - Also, Gas and hydro shows similar trends and usage .
# - While the least capacity used were oil,biomass,wind and solar.

# %% [markdown]
# ### capacity_mw V/S  Other contionous /Discreate data .

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnum=1

X = gpp.drop(columns=['capacity_mw'])
y = gpp['capacity_mw']

for col in X:
    if plotnum<=23:
        plt.subplot(5,5,plotnum)
        sns.scatterplot(X[col],y)
        plt.xlabel(col,fontsize=20)
        plt.ylabel('capacity_mw',fontsize=20)
    plotnum+=1
plt.tight_layout()

# %% [markdown]
# #### KEY OBSERVATIONS -
# - As observed, there is a linear relationship between columns-'generation_gwh_2014',generation_gwh_2015,generation_gwh_2016,generation_gwh_2017,generation_gwh_2018.

# %% [markdown]
# ### 'primary_fuel' vs Continuous/Discrete Data Columns

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnum=1

x = gpp.drop(columns=['primary_fuel'])
y = gpp['primary_fuel']

for col in X:
    if plotnum<=23:
        plt.subplot(5,5,plotnum)
        sns.scatterplot(X[col],y)
        plt.xlabel(col,fontsize=20)
        plt.ylabel('primary_fuel',fontsize=20)
    plotnum+=1
plt.tight_layout()

# %% [markdown]
# #### KEY OBSERVATIONS -
# - The observations made from the above graph is that the highest power generation capacity belongs to coal followed by hydro and Nuclear plants.
# - Thereby ,From 2014 to 2018 electricity is generated highest by coal power plants and 2nd highest is by Hydro power plants.

# %% [markdown]
# ### VISUALISING YEAR WISE TREND OF CAPACITY_MW IN RELATION TO PRIMARY FUELS USED.

# %%
# IN 2014- 

plt.figure(figsize=(15,8))
sns.relplot('capacity_mw','generation_gwh_2014', data = gpp, hue ='primary_fuel')

# %% [markdown]
# #### - In the year 2014, coal as a primary fuel has the highest capacity and generated highest electricity globally.

# %%
#In 2015

plt.figure(figsize=(15,10))
sns.relplot('capacity_mw','generation_gwh_2015', data = gpp, hue ='primary_fuel')

# %% [markdown]
# #### - Comparing to other power plants, power plants with coal as primary fuel is generation more electricity.Similar trends were seen in the previous year as well.

# %%
# In 2016

plt.figure(figsize=(15,10))
sns.relplot('capacity_mw','generation_gwh_2016', data = gpp, hue ='primary_fuel')

# %% [markdown]
# #### - In 2016,Power plants which has coal as primary fuel are having highest capacity and are having the highest generation of electricity generation.wind and gas as priary fuels were least used.

# %%
# In 2017-

plt.figure(figsize=(15,10))
sns.relplot('capacity_mw','generation_gwh_2017', data = gpp, hue ='primary_fuel')

# %% [markdown]
# #### - In 2017,Power plants which has coal as primary fuel are having highest capacity and are having the highest generation of electricity generation.

# %%
#In 2018-

plt.figure(figsize=(15,10))
sns.relplot('capacity_mw','generation_gwh_2018', data = gpp, hue ='primary_fuel')

# %% [markdown]
# #### - In 2018,Power plants which has coal as primary fuel are having highest capacity and are having the highest generation of electricity generation.wind and gas were least used .

# %% [markdown]
# ### Since there is only one value in columns 'other_fuel2', we can drop these column along with , 'year_of_capacity_data' as these are not contributing any impact on the predictions.

# %%
gpp.drop(['other_fuel2', 'year_of_capacity_data'],axis = 1,inplace = True)

# %%
gpp.shape
# Out:
# (907, 11)

# %% [markdown]
# ### ENCODING THE CATEGORICAL COLUMNS -

# %%
# Encoding the data.
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
gpp['primary_fuel'] = le.fit_transform(gpp['primary_fuel'].values.reshape(-1,1))    
gpp['other_fuel1'] = le.fit_transform(gpp['other_fuel1'].values.reshape(-1,1))

# %%
gpp.dtypes
# Out:
# capacity_mw            float64
# latitude               float64
# longitude              float64
# primary_fuel             int32
# other_fuel1              int32
# commissioning_year     float64
# generation_gwh_2014    float64
# generation_gwh_2015    float64
# generation_gwh_2016    float64
# generation_gwh_2017    float64
# generation_gwh_2018    float64
# dtype: object

# %% [markdown]
# ### CHECKING THE CORRELATION MATRIX-

# %%
Correlation = gpp.corr()


#Plotting the correlation of columns

plt.figure(figsize=[15,10])
sns.heatmap(Correlation,annot = True, fmt = '0.2f', cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### KEY OBSERVATIONS -
# - Here as we see that the generation_gwh_2014, generation_gwh_2015,generation_gwh_2016,generation_gwh_2017 and generation_gwh_2018 are positively correlated with the target variabke 'capacity_mw'.
# - Whereas , latitude, longitude,primary_fuel,other_fuel1 and commisioning_year is negatively correlated with the target variable ' capacity_mw'.

# %% [markdown]
# #### Considering 'capacity_mw' as target Variable -

# %%
print(Correlation['capacity_mw'].drop('capacity_mw').sort_values(ascending = False))

plt.figure(figsize = [15,5])
Correlation['capacity_mw'].sort_values(ascending= False).drop('capacity_mw').plot(kind = 'bar', color ='lime')
plt.xlabel('Column Names', fontsize = 12)
plt.ylabel('Correlation', fontsize = 12)
plt.title('Correlation with Target Column')
plt.show()
# Out:
# generation_gwh_2018    0.773456
# generation_gwh_2017    0.757585
# generation_gwh_2016    0.742221
# generation_gwh_2015    0.711190
# generation_gwh_2014    0.694350
# commissioning_year     0.274292
# longitude              0.195882
# latitude               0.050984
# other_fuel1            0.003105
# primary_fuel          -0.380395
# Name: capacity_mw, dtype: float64

# %% [markdown]
# #### KEY OBSERVATIONS -
#
# - Except the column 'primary_fuel', all other columns are having positve correlation with the target variable 'capacity_mw'.
# - The column 'generation_gwh_2018' is having highest positive correlation with the target column 'capacity_mw'.
# - The column 'primary_fuel' is the only column having negative correlation with the target column 'capacity_mw'.
# - The column 'other_fuel1' is having the least positive correlation with the target column 'capacity_mw'.

# %% [markdown]
# #### Considering 'primary_fuel' as target Variable -

# %%
print(Correlation['primary_fuel'].drop('primary_fuel').sort_values(ascending = False))
plt.figure(figsize = [15,5])
Correlation['primary_fuel'].sort_values(ascending= False).drop('primary_fuel').plot(kind = 'bar', color ='deeppink')
plt.xlabel('Column Names', fontsize = 12)
plt.ylabel('Correlation', fontsize = 12)
plt.title('Correlation with Target Column')
plt.show()
# Out:
# other_fuel1            0.004912
# latitude              -0.010204
# generation_gwh_2014   -0.124769
# generation_gwh_2015   -0.124828
# commissioning_year    -0.126650
# generation_gwh_2016   -0.131051
# generation_gwh_2017   -0.132003
# generation_gwh_2018   -0.136983
# longitude             -0.347948
# capacity_mw           -0.380395
# Name: primary_fuel, dtype: float64

# %% [markdown]
# #### KEY OBSERVATIONS -
#
# - Except the column 'other_fuel1', all other columns are having positve correlation with the target variable 'primary_fuel'.
# - The column 'other_fuel1' is the only column having the positive correlation with the target variable 'primary_fuel'.
# - The column 'capacity_mw' is having highest negative correlation with the target variable 'primary fuel'.
# - The column 'latitude' is having the least negative correlation with the target variable 'primary_fuel'.

# %% [markdown]
# ### DETECTING OUTLIERS-

# %%
#Checking for outliers -

gpp.plot(kind='box',subplots=True,layout=(3,4),figsize=(16,12))
# Out:
# capacity_mw               AxesSubplot(0.125,0.657941;0.168478x0.222059)
# latitude               AxesSubplot(0.327174,0.657941;0.168478x0.222059)
# longitude              AxesSubplot(0.529348,0.657941;0.168478x0.222059)
# primary_fuel           AxesSubplot(0.731522,0.657941;0.168478x0.222059)
# other_fuel1               AxesSubplot(0.125,0.391471;0.168478x0.222059)
# commissioning_year     AxesSubplot(0.327174,0.391471;0.168478x0.222059)
# generation_gwh_2014    AxesSubplot(0.529348,0.391471;0.168478x0.222059)
# generation_gwh_2015    AxesSubplot(0.731522,0.391471;0.168478x0.222059)
# generation_gwh_2016          AxesSubplot(0.125,0.125;0.168478x0.222059)
# generation_gwh_2017       AxesSubplot(0.327174,0.125;0.168478x0.222059)
# generation_gwh_2018       AxesSubplot(0.529348,0.125;0.168478x0.222059)
# dtype: object

# %% [markdown]
# #### - Except the column latitude and primary_fuel, all other columns are having outliers.

# %% [markdown]
# ### CHECKING SKEWNESS

# %%
Skew = gpp.skew()
Skew.sort_values(ascending = False)
# Out:
# generation_gwh_2015     5.364134
# generation_gwh_2017     5.110952
# generation_gwh_2016     5.068427
# generation_gwh_2014     5.035446
# generation_gwh_2018     4.937907
# capacity_mw             3.123576
# longitude               1.141881
# primary_fuel            0.472251
# latitude               -0.149698
# commissioning_year     -1.399359
# other_fuel1           -20.453120
# dtype: float64

# %% [markdown]
# #### KEY OBSERVATIONS -
# - From the above observations, we can see that extreme skewness is present in most of the columns. But the columns 'primary_fuel','other_fuel1' are categorical in nature and we have encoded them for the model building. So the skewnnes of these columns are irrelevant.
# - The column 'capacity_mw' is the target column if we consider this as a regression problem.
# - Rest of the columns are having skewness.

# %% [markdown]
# ### DATA CLEANING -Removing skewness and Outliers .

# %% [markdown]
# #### Target 'primary_fuel' has categorical type of data - classification approach

# %%
#Splitting the data into 'x' and 'y' labels-

x=gpp.drop('primary_fuel',axis=1)
y=gpp['primary_fuel']

print(x.shape)
print(y.shape)
print(y.value_counts())
# Out:
# (907, 10)
# (907,)
# 1    258
# 3    251
# 6    127
# 7    123
# 2     69
# 0     50
# 5     20
# 4      9
# Name: primary_fuel, dtype: int64

# %% [markdown]
# #### - There is imbalance in our target variable data.Let try to balance the data .

# %%
# Using SMOTE to balance the categorical data-

from imblearn.over_sampling import SMOTE    # Importing library
sm= SMOTE()
x,y=sm.fit_resample(x,y)
y
# Out:
# 0       6
# 1       1
# 2       7
# 3       2
# 4       1
#        ..
# 2059    7
# 2060    7
# 2061    7
# 2062    7
# 2063    7
# Name: primary_fuel, Length: 2064, dtype: int32

# %%
print(y.value_counts())
# Out:
# 6    258
# 1    258
# 7    258
# 2    258
# 3    258
# 0    258
# 5    258
# 4    258
# Name: primary_fuel, dtype: int64

# %% [markdown]
# #### - The data is now balanced withequal distribution.

# %%
#Removing skewness from the data with standard limit as +/-0.5. -

x.skew().sort_values(ascending=False)[np.abs(x.skew())>0.5]
# Out:
# generation_gwh_2015    5.275645
# generation_gwh_2017    4.965437
# generation_gwh_2014    4.897019
# generation_gwh_2016    4.805462
# generation_gwh_2018    4.799482
# capacity_mw            2.781296
# longitude              1.537218
# commissioning_year    -1.582711
# other_fuel1           -8.387177
# dtype: float64

# %%
from sklearn.preprocessing import power_transform

def skew(col):
    x[col]=power_transform((x[col].values.reshape(-1,1)))
    
    
skew('generation_gwh_2015')
skew('generation_gwh_2014')
skew('generation_gwh_2016')
skew('generation_gwh_2018')
skew('generation_gwh_2017')
skew('capacity_mw')
skew('longitude')
skew('commissioning_year')
skew('other_fuel1')

# %%
x.skew().sort_values(ascending=False)
# Out:
# commissioning_year     0.123193
# latitude               0.047620
# capacity_mw            0.027825
# generation_gwh_2014    0.013660
# longitude              0.000000
# generation_gwh_2015   -0.020217
# generation_gwh_2017   -0.129416
# generation_gwh_2016   -0.169244
# generation_gwh_2018   -0.211544
# other_fuel1           -7.848903
# dtype: float64

# %% [markdown]
# #### - Skewness is reduced in all the columns.

# %%
# Removing Outliers-
# ~'METHOD-ZSCORE'~

from scipy.stats import zscore

gpp=x.copy()

gpp.drop('other_fuel1',axis=1,inplace=True)

gpp['primary_fuel']=y.copy()

z=np.abs(zscore(gpp))

gpp_new= gpp[(z < 3).all(axis=1)]   #taking 3 as threshold value

gpp_new['other_fuel1'] = x['other_fuel1']
gpp_new
# Out:
#       capacity_mw   latitude     longitude  commissioning_year  \
# 0       -1.772899  28.183900 -2.361999e-14            1.717030
# 1        0.214737  24.766300 -1.074141e-14           -0.112919
# 2       -0.288301  21.903800 -7.141510e-14           -0.112919
# 3        0.386533  23.871200  6.369905e-14            0.723405
# 4        1.685481  21.960300  3.747003e-14            2.360306
# ...           ...        ...           ...                 ...
# 2059    -0.803294  23.749019 -5.359602e-14           -0.112919
# 2060    -1.056125   9.477189  1.174061e-14           -0.112919
# 2061    -1.329370  22.604582  3.025358e-15           -0.112919
# 2062     0.229418  16.695883 -1.137979e-15           -0.112919
# 2063    -0.773472  14.639468  3.330669e-15           -0.112919
#
#       generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0                0.264102             0.305687             0.324758
# 1                0.264102             0.305687             0.324758
# ...

# %%
#if we check the previous data dimension along with the dropped column 'other_fuel1'

gpp['other_fuel1']=x['other_fuel1']
gpp.shape
# Out:
# (2064, 11)

# %%
gpp_new.shape
# Out:
# (2021, 11)

# %%
# Checking the percentage of data loss -

loss = (gpp.shape[0]-gpp_new.shape[0])/gpp.shape[0]*100
loss
# Out:
# 2.083333333333333

# %%
# METHOD- IQR METHOD  (Inter Quantile Range)

# addressing outliers using the IOR:
x = x.drop('other_fuel1',axis = 1)


Q1 =x.quantile(0.25)
Q3 =x.quantile(0.75)
IQR = Q3 - Q1

gpp_data = gpp[~((gpp < (Q1 - 1.5 * IQR)) |(gpp > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
gpp_data.shape
# Out:
# (1040, 11)

# %%
gpp.shape
# Out:
# (2064, 11)

# %%
# Checking the percentage of data loss 

data_loss = (gpp.shape[0]-gpp_data.shape[0])/gpp.shape[0]*100
data_loss
# Out:
# 49.6124031007752

# %% [markdown]
# #### - After applying both the methods to remove outliers,what we observe is we are losing 49.61 % of data from the dataset after  using inter quartile range method which is not acceptable as the percentage of data loss is huge . So we can move forward with the zscore method as the percentage of data loss is much less (2.08 %) comparative to other method.

# %% [markdown]
# ### CHECKING MULTICOLLINEARITY

# %%
x = gpp_new.drop(['primary_fuel'],axis = 1)
y = gpp_new['primary_fuel']
z = x.columns

print(x.shape)
print(y.shape)
# Out:
# (2064, 10)
# (2064,)

# %% [markdown]
# #### APPLYING STANDARD SCALER-

# %%
#Using standard scaler to scale the data 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x = sc.fit_transform(x)
x = pd.DataFrame(x,columns = z)
x
# Out:
#       capacity_mw  latitude  longitude  commissioning_year  \
# 0       -1.772899  1.461645  -0.901945            1.717030
# 1        0.214737  0.853399  -0.410037           -0.112919
# 2       -0.288301  0.343947  -2.727516           -0.112919
# 3        0.386533  0.694095   2.433274            0.723405
# 4        1.685481  0.354003   1.431436            2.360306
# ...           ...       ...        ...                 ...
# 2059    -0.803294  0.672349  -2.046902           -0.112919
# 2060    -1.056125 -1.867673   0.448681           -0.112919
# 2061    -1.329370  0.468669   0.115795           -0.112919
# 2062     0.229418 -0.582929  -0.043227           -0.112919
# 2063    -0.773472 -0.948919   0.127457           -0.112919
#
#       generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0                0.264102             0.305687             0.324758
# 1                0.264102             0.305687             0.324758
# ...

# %% [markdown]
# #### CALCULATE V.I.F SCORE -

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def vifscore(x):
    vif = pd.DataFrame()
    vif['Column Name'] = x.columns
    vif['VIF Factor'] = [variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    return(vif.sort_values('VIF Factor',ascending = False))

# %%
vifscore(x)
# Out:
#            Column Name  VIF Factor
# 6  generation_gwh_2016   18.768027
# 8  generation_gwh_2018   14.940675
# 5  generation_gwh_2015   13.293615
# 7  generation_gwh_2017    8.458835
# 4  generation_gwh_2014    7.415787
# 9          other_fuel1    1.345260
# 0          capacity_mw    1.200395
# 2            longitude    1.164664
# 3   commissioning_year    1.120598
# 1             latitude    1.042665

# %% [markdown]
# #### - There is multicollinearity present in our data.The VIF Score of 'generation_gwh_2016','generation_gwh_2018' and 'generation_gwh_2015' are high but we cannot further miss-out more data from the dataset, we will proceed with further ahead keep this data same .

# %% [markdown]
# ## MODEL BUILDING
#
# #### CLASSIFICATION APPROACH using 'primary_fuel' target variable

# %% [markdown]
# #### SPLITTING THE DATA INTO INPUT AND OUTPUT VARIABLE

# %%
input = x.copy()
output = y.copy()

# %%
# Models:
from sklearn.model_selection import train_test_split


from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# for cross validation
from sklearn.model_selection import cross_val_score

#Matrics for Evaluation
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,plot_roc_curve,roc_curve,roc_auc_score

# %%
rf = RandomForestClassifier()
lr = LogisticRegression()
knn = KNeighborsClassifier()
svc = SVC()
dtc = DecisionTreeClassifier()
abc = AdaBoostClassifier()
gbc = GradientBoostingClassifier()

# %% [markdown]
# #### FINDING BEST RANDOM STATE-

# %%
maxAcc = 0
maxRS = 0
for i in range(1,100):
    x_train,x_test,y_train,y_test = train_test_split(input,output,test_size =0.20, random_state = i)
   
    rf.fit(x_train,y_train)
    pred = rf.predict(x_test)
    acc  = accuracy_score(y_test,pred)
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i
print(f"Best Accuracy is: {maxAcc} on random_state: {maxRS}")
# Out:
# Best Accuracy is: 0.9128329297820823 on random_state: 64

# %%
#Applying the best selected random state -

x_train,x_test,y_train,y_test = train_test_split(input,output,test_size =0.20, random_state = 69)

# %%
# Training all the models together-

rf.fit(x_train,y_train.ravel())
lr.fit(x_train,y_train.ravel())
knn.fit(x_train,y_train.ravel())
svc.fit(x_train,y_train.ravel())
dtc.fit(x_train,y_train.ravel())
abc.fit(x_train,y_train.ravel())
gbc.fit(x_train,y_train.ravel())
# Out:
# GradientBoostingClassifier()

# %% [markdown]
# #### TESTING ALL MODELS ONE BY ONE -

# %% [markdown]
# ### 1) RANDOM FOREST CLASSIFIER

# %%
predrf = rf.predict(x_test)
rfreport = pd.DataFrame(classification_report(y_test, predrf ,output_dict=True))

print("\n=======================TEST Result===========================")

print(f"Accuracy score:{accuracy_score(y_test,predrf)*100:.2f}%")
print("_______________________________________________________________")
print(f"CLASSIFICATION REPORT:\n{rfreport}")
print("________________________________________________________________")
print(f" Confusion Matrix:\n{confusion_matrix(y_test,predrf)}\n")
# Out:
# =======================TEST Result===========================
# Accuracy score:89.35%
# _______________________________________________________________
# CLASSIFICATION REPORT:
#                    0          1          2          3          4          5  \
# precision   0.919355   0.818182   0.869565   0.912281   0.903846   0.910714
# recall      0.966102   0.765957   0.784314   0.881356   1.000000   0.962264
# f1-score    0.942149   0.791209   0.824742   0.896552   0.949495   0.935780
# support    59.000000  47.000000  51.000000  59.000000  47.000000  53.000000
#
#                    6          7  accuracy   macro avg  weighted avg
# precision   0.869565   0.920000  0.893462    0.890439      0.892709
# recall      0.930233   0.851852  0.893462    0.892760      0.893462
# f1-score    0.898876   0.884615  0.893462    0.890427      0.891950
# support    43.000000  54.000000  0.893462  413.000000    413.000000
# ________________________________________________________________
# ...

# %% [markdown]
# ### 2) LOGISTIC REGRESSION

# %%
predlr = lr.predict(x_test)
lrreport = pd.DataFrame(classification_report(y_test, predlr ,output_dict=True))

print("\n=======================TEST Result===========================")

print(f"Accuracy score:{accuracy_score(y_test,predlr)*100:.2f}%")
print("_______________________________________________________________")
print(f"CLASSIFICATION REPORT:\n{lrreport}")
print("________________________________________________________________")
print(f" Confusion Matrix:\n{confusion_matrix(y_test,predlr)}\n")
# Out:
# =======================TEST Result===========================
# Accuracy score:52.06%
# _______________________________________________________________
# CLASSIFICATION REPORT:
#                    0          1          2          3          4          5  \
# precision   0.442623   0.590909   0.675000   0.595238   0.750000   0.666667
# recall      0.457627   0.553191   0.529412   0.423729   0.893617   0.377358
# f1-score    0.450000   0.571429   0.593407   0.495050   0.815534   0.481928
# support    59.000000  47.000000  51.000000  59.000000  47.000000  53.000000
#
#                    6          7  accuracy   macro avg  weighted avg
# precision   0.600000   0.150000  0.520581    0.558805      0.551852
# recall      0.837209   0.222222  0.520581    0.536796      0.520581
# f1-score    0.699029   0.179104  0.520581    0.535685      0.524167
# support    43.000000  54.000000  0.520581  413.000000    413.000000
# ________________________________________________________________
# ...

# %% [markdown]
# ### 3) KNeighborsClassifier

# %%
predknn= knn.predict(x_train)

knnreport = pd.DataFrame(classification_report(y_train, predknn, output_dict = True))
print("\n=======================TRAIN Result===========================")
print(f"Accuracy score:{accuracy_score(y_train, predknn)*100:.2f}%")
print("_______________________________________________________________")
print(f"CLASSIFICATION REPORT:\n{knnreport}")
print("________________________________________________________________")
print(f" Confusion Matrix:\n{confusion_matrix(y_train, predknn)}\n")
# Out:
# =======================TRAIN Result===========================
# Accuracy score:87.83%
# _______________________________________________________________
# CLASSIFICATION REPORT:
#                     0           1           2           3           4  \
# precision    0.873874    0.825397    0.844221    0.948718    0.905579
# recall       0.974874    0.739336    0.811594    0.743719    1.000000
# f1-score     0.921615    0.780000    0.827586    0.833803    0.950450
# support    199.000000  211.000000  207.000000  199.000000  211.000000
#
#                     5           6           7  accuracy    macro avg  \
# precision    0.905830    0.910377    0.820276  0.878256     0.879284
# recall       0.985366    0.897674    0.872549  0.878256     0.878139
# f1-score     0.943925    0.903981    0.845606  0.878256     0.875871
# support    205.000000  215.000000  204.000000  0.878256  1651.000000
#
#            weighted avg
# precision      0.879133
# recall         0.878256
# ...

# %% [markdown]
# ### 4) SVC

# %%
predsvc = svc.predict(x_test)

svcreport = pd.DataFrame(classification_report(y_test, predsvc , output_dict=True))
print("\n=======================TEST Result===========================")
print(f"Accuracy score:{accuracy_score(y_test,predsvc)*100:.2f}%")
print("_______________________________________________________________")
print(f"CLASSIFICATION REPORT:\n{svcreport}")
print("________________________________________________________________")
print(f" Confusion Matrix:\n{confusion_matrix(y_test,predsvc)}\n")
# Out:
# =======================TEST Result===========================
# Accuracy score:73.12%
# _______________________________________________________________
# CLASSIFICATION REPORT:
#                    0          1          2          3          4          5  \
# precision   0.615385   0.756098   0.785714   0.975610   0.870370   0.771930
# recall      0.949153   0.659574   0.647059   0.677966   1.000000   0.830189
# f1-score    0.746667   0.704545   0.709677   0.800000   0.930693   0.800000
# support    59.000000  47.000000  51.000000  59.000000  47.000000  53.000000
#
#                    6          7  accuracy   macro avg  weighted avg
# precision   0.647059   0.500000  0.731235    0.740271      0.741210
# recall      0.767442   0.333333  0.731235    0.733089      0.731235
# f1-score    0.702128   0.400000  0.731235    0.724214      0.722747
# support    43.000000  54.000000  0.731235  413.000000    413.000000
# ________________________________________________________________
# ...

# %% [markdown]
# ### 5) DecisionTreeClassifier

# %%
preddtc= dtc.predict(x_test)

report = pd.DataFrame(classification_report(y_test, preddtc, output_dict = True))
print("\n=======================Train Result===========================")
print(f"Accuracy score:{accuracy_score(y_test,preddtc)*100:.2f}%")
print("_______________________________________________________________")
print(f"CLASSIFICATION REPORT:\n{report}")
print("________________________________________________________________")
print(f" Confusion Matrix:\n{confusion_matrix(y_test,preddtc)}\n")
# Out:
# =======================Train Result===========================
# Accuracy score:83.29%
# _______________________________________________________________
# CLASSIFICATION REPORT:
#                    0          1          2          3          4          5  \
# precision   0.915254   0.627119   0.772727   0.909091   0.916667   0.920000
# recall      0.915254   0.787234   0.666667   0.847458   0.936170   0.867925
# f1-score    0.915254   0.698113   0.715789   0.877193   0.926316   0.893204
# support    59.000000  47.000000  51.000000  59.000000  47.000000  53.000000
#
#                    6          7  accuracy   macro avg  weighted avg
# precision   0.813953   0.800000   0.83293    0.834351      0.839136
# recall      0.813953   0.814815   0.83293    0.831184      0.832930
# f1-score    0.813953   0.807339   0.83293    0.830895      0.834247
# support    43.000000  54.000000   0.83293  413.000000    413.000000
# ________________________________________________________________
# ...

# %% [markdown]
# ### 6) AdaBoostClassifier

# %%
predab = abc.predict(x_test)

abreport = pd.DataFrame(classification_report(y_test, predab , output_dict=True))
print("\n=======================TEST Result===========================")
print(f"Accuracy score:{accuracy_score(y_test,predab)*100:.2f}%")
print("_______________________________________________________________")
print(f"CLASSIFICATION REPORT:\n{abreport}")
print("________________________________________________________________")
print(f" Confusion Matrix:\n{confusion_matrix(y_test,predab)}\n")
# Out:
# =======================TEST Result===========================
# Accuracy score:30.02%
# _______________________________________________________________
# CLASSIFICATION REPORT:
#               0     1          2          3          4     5          6     7  \
# precision   0.0   0.0   0.405405   0.833333   0.661290   0.0   0.163498   0.0
# recall      0.0   0.0   0.588235   0.169492   0.872340   0.0   1.000000   0.0
# f1-score    0.0   0.0   0.480000   0.281690   0.752294   0.0   0.281046   0.0
# support    59.0  47.0  51.000000  59.000000  47.000000  53.0  43.000000  54.0
#
#            accuracy   macro avg  weighted avg
# precision  0.300242    0.257941      0.261388
# recall     0.300242    0.328758      0.300242
# f1-score   0.300242    0.224379      0.214389
# support    0.300242  413.000000    413.000000
# ________________________________________________________________
#  Confusion Matrix:
# [[ 0  0  0  0  0  0 59  0]
#  [ 0  0 20  1 17  0  9  0]
#  [ 0  0 30  0  2  0 19  0]
# ...

# %% [markdown]
# ### 7) GradientBoostingClassifier

# %%
predgb = gbc.predict(x_test)

gbreport = pd.DataFrame(classification_report(y_test, predgb , output_dict=True))
print("\n=======================TEST Result===========================")
print(f"Accuracy score:{accuracy_score(y_test,predgb)*100:.2f}%")
print("_______________________________________________________________")
print(f"CLASSIFICATION REPORT:\n{gbreport}")
print("________________________________________________________________")
print(f" Confusion Matrix:\n{confusion_matrix(y_test,predgb)}\n")
# Out:
# =======================TEST Result===========================
# Accuracy score:87.17%
# _______________________________________________________________
# CLASSIFICATION REPORT:
#                    0          1          2          3          4          5  \
# precision   0.850746   0.772727   0.840909   0.913793   0.870370   0.928571
# recall      0.966102   0.723404   0.725490   0.898305   1.000000   0.981132
# f1-score    0.904762   0.747253   0.778947   0.905983   0.930693   0.954128
# support    59.000000  47.000000  51.000000  59.000000  47.000000  53.000000
#
#                    6          7  accuracy   macro avg  weighted avg
# precision   0.863636   0.913043  0.871671    0.869225      0.871367
# recall      0.883721   0.777778  0.871671    0.869492      0.871671
# f1-score    0.873563   0.840000  0.871671    0.866916      0.869045
# support    43.000000  54.000000  0.871671  413.000000    413.000000
# ________________________________________________________________
# ...

# %% [markdown]
# ### CHECKING CROSS VALIDATION

# %%
#CV score of Random forest classifier-

print(f"CV Score of RF:{cross_val_score(rf,input,output,cv=5).mean()*100:.2f}%")
# Out:
# CV Score of RF:88.61%

# %%
#CV Score of Logistic Regression - 

print(f"CV Score of SVC:{cross_val_score(svc,input,output,cv = 5).mean()*100:.2f}%")
# Out:
# CV Score of SVC:73.64%

# %%
#CV Score of K-Neighbors Classifier-

print(f"CV Score of KNN:{cross_val_score(knn,input,output,cv = 5).mean()*100:.2f}%")
# Out:
# CV Score of KNN:81.78%

# %%
#CV Score of Support Vector Classifier - 

print(f"CV Score of SVC:{cross_val_score(svc,input,output,cv = 5).mean()*100:.2f}%")
# Out:
# CV Score of SVC:73.64%

# %%
#CV Score of Decision Tree Classifier - 

print(f"CV Score of DT:{cross_val_score(dtc,input,output,cv = 5).mean()*100:.2f}%")
# Out:
# CV Score of DT:82.51%

# %%
#CV Score of Adaboost Classifier - 

print(f"CV Score of SVC:{cross_val_score(abc,input,output,cv = 5).mean()*100:.2f}%")
# Out:
# CV Score of SVC:27.37%

# %%
#CV Score of Gradient Boosting Classifier - 

print(f"CV score of GB:{cross_val_score(gbc,input,output,cv = 5).mean()*100:.2f}%")
# Out:
# CV score of GB:86.58%

# %% [markdown]
# #### - After cross validations, the models are performing well  and provding the best accuracy score. Out of that, the RandomForest Classifier(rfc) is providing the maximum accuracy score of 91.53 % with a cross validation mean score of 88.13% for 5 fold cross validations. So we will consider the RANDOM FORST CLASSIFIER model as the best model.

# %% [markdown]
# ## HYPERPARAMETER TUNNING OF RANDOM FOREST CLASSIFIER(rfc)

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {'n_estimators':[100,125,150],
             'criterion': ['gini','entropy'],
             'max_features': ['auto','sqrt','log2'],
             'class_weight':['balanced','balanced_subsample']}

grid = GridSearchCV(estimator = RandomForestClassifier(),param_grid=parameters, cv = 5)

# %%
grid.fit(input,output)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'class_weight': ['balanced', 'balanced_subsample'],
#                          'criterion': ['gini', 'entropy'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [100, 125, 150]})

# %%
grid.best_score_
# Out:
# 0.8905028326947036

# %%
grid.best_params_
# Out:
# {'class_weight': 'balanced_subsample',
#  'criterion': 'entropy',
#  'max_features': 'auto',
#  'n_estimators': 150}

# %%
rfc = RandomForestClassifier(n_estimators=125,criterion='entropy',max_features='sqrt',class_weight='balanced_subsample')
rfc.fit(x_train,y_train)
y_pred=rfc.predict(x_test)

rfc_conf_mat = confusion_matrix(y_test,y_pred)
print('con_mat: ','\n',rfc_conf_mat)

print('Accuracy of Random Forest Classifier After Hyperparameter Tuning==> ',accuracy_score(y_test,y_pred)*100)
# Out:
# con_mat:
#  [[57  1  0  0  0  0  0  1]
#  [ 0 37  3  3  3  0  1  0]
#  [ 2  2 40  1  1  3  1  1]
#  [ 0  3  3 52  0  1  0  0]
#  [ 0  0  0  0 47  0  0  0]
#  [ 0  1  0  0  0 51  0  1]
#  [ 1  1  0  0  0  0 40  1]
#  [ 2  0  0  0  0  1  4 47]]
# Accuracy of Random Forest Classifier After Hyperparameter Tuning==>  89.83050847457628

# %%
# classification report
Report = classification_report(y_test,y_pred)
print(Report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94        59
#            1       0.82      0.79      0.80        47
#            2       0.87      0.78      0.82        51
#            3       0.93      0.88      0.90        59
#            4       0.92      1.00      0.96        47
#            5       0.91      0.96      0.94        53
#            6       0.87      0.93      0.90        43
#            7       0.92      0.87      0.90        54
#
#     accuracy                           0.90       413
#    macro avg       0.90      0.90      0.90       413
# weighted avg       0.90      0.90      0.90       413

# %% [markdown]
# #### - After hyper parameter tuning, our model is still performing better with almost same accuracy. The RandomForest Classifier model is performing well after hyperparameter tunings is 91.04%.

# %% [markdown]
# ### PLOTTING AUC_ROC_CURVE

# %%
model =['lr','rf','svc','abc','gbc','knn','dtc']

# %%
# Using User defined function to plot AUC ROC curve for different models-

def auc_roc(model):
    pred_prob = model.predict_proba(x_test)[:,1]
    fpr,tpr,thresholds = roc_curve(y_test,pred_prob,pos_label=True)
    auc_score = roc_auc_score(y_test, model.predict_proba(x_test),multi_class='ovr')
    plt.plot([0,1],[0,1],'k--')
    plt.plot(fpr, tpr, label = 'AUC ='+str(round(auc_score,2)))
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc = 'lower right')
    plt.title(model)
    plt.show()

# %% [markdown]
# ### 1) LogisticRegression

# %%
auc_roc(lr)

# %% [markdown]
# ### 2) Random forest classifier

# %%
auc_roc(rf)

# %% [markdown]
# ### 3) K-Neighbors Classifier-

# %%
auc_roc(knn)

# %% [markdown]
# ### 4) Decision tree classifier-

# %%
auc_roc(dtc)

# %% [markdown]
# ### 5)Gradient boosting clasifier

# %%
auc_roc(gbc)

# %% [markdown]
# #### In auc_roc curve, the RFC  model are performing well with a auc roc score of 99%. Also RF model is performing well with all the tests, validations, and tuning, we will consider the Random Forest Classifier (rfc) model as the best model.
# ### The RANDOM FOREST CLASSIFIER model is providing a accuracy score of 91.04%

# %% [markdown]
# ### SAVING THE MODEL

# %%
import pickle

filename = 'Global powerplant prediction model-classification.pkl'
pickle.dump(rf,open(filename,'wb'))

# %% [markdown]
# ### CONCLUSION-

# %%
Actual = np.array(y_test)
predicted = np.round(np.array(rf.predict(x_test)),0)
gpp_prediction = pd.DataFrame({'Actual Primary Fuel':Actual,'Predicted Primary Fuel':predicted})
gpp_prediction.head(10)
# Out:
#    Actual Primary Fuel  Predicted Primary Fuel
# 0                    7                       7
# 1                    3                       3
# 2                    7                       7
# 3                    3                       3
# 4                    0                       0
# 5                    4                       4
# 6                    2                       2
# 7                    1                       1
# 8                    2                       2
# 9                    0                       0

# %% [markdown]
# #### Classification model created successfully. Our model is performing well  with Random forest Classifier model .

# %% [markdown]
# ###  Target 'capacity_mw' has continuous data - Regression approach.

# %%
#Splitting the data into 'x' and 'y' labels-

x=gpp.drop('capacity_mw',axis =1)
y=gpp['capacity_mw']

print(x.shape)
print(y.shape)
print(y.value_counts())
# Out:
# (907, 10)
# (907,)
# 5.0       39
# 10.0      22
# 600.0     20
# 15.0      20
# 1200.0    19
#           ..
# 291.0      1
# 645.0      1
# 41.4       1
# 17.5       1
# 106.6      1
# Name: capacity_mw, Length: 361, dtype: int64

# %% [markdown]
# ### START WITH REMOVING THE SKEWNESS AND OUTLIERS

# %%
x.skew().sort_values(ascending=False)[np.abs(x.skew())>0.5]
# Out:
# generation_gwh_2015     5.364134
# generation_gwh_2017     5.110952
# generation_gwh_2016     5.068427
# generation_gwh_2014     5.035446
# generation_gwh_2018     4.937907
# longitude               1.141881
# commissioning_year     -1.399359
# other_fuel1           -20.453120
# dtype: float64

# %% [markdown]
# #### - Here the columns such as 'generation_gwh_2015', 'generation_gwh_2017', 'generation_gwh_2016', 'generation_gwh_2014', 'generation_gwh_2018','longitude', 'commissioning_year', 'other_fuel1'  are having high skewness .

# %% [markdown]
# #### from sklearn.preprocessing import power_transform
#
# def skew(col):
#     x[col]=power_transform((x[col].values.reshape(-1,1)))

# %%
skew('generation_gwh_2015')
skew('generation_gwh_2017')
skew('generation_gwh_2016')
skew('generation_gwh_2014')
skew('generation_gwh_2018')
skew('primary_fuel')
skew('longitude')
skew('commissioning_year')

# %%
x.skew().sort_values(ascending = False)
# Out:
# generation_gwh_2014     0.123226
# generation_gwh_2015     0.074582
# generation_gwh_2016     0.041821
# generation_gwh_2017     0.018337
# longitude               0.002926
# generation_gwh_2018     0.000783
# primary_fuel           -0.047067
# commissioning_year     -0.080999
# latitude               -0.149698
# other_fuel1           -20.453120
# dtype: float64

# %% [markdown]
# skewness reduced

# %% [markdown]
# ### REMOVING OURLIERS  ZSCORE METHOD -

# %%
from scipy.stats import zscore

gpp1 = x.copy()
gpp1.drop('other_fuel1',axis = 1, inplace = True)    #removing the categorical column.
gpp1['capacity_mw'] = y.copy()
z = np.abs(zscore(gpp1))
gpp_2= gpp1[(z < 3).all(axis=1)]   #taking 3 as threshold value

gpp_2['other_fuel1'] = x['other_fuel1']
gpp_2
# Out:
#      latitude  longitude  primary_fuel  commissioning_year  \
# 0     28.1839  -0.952545      1.171313            1.252259
# 1     24.7663  -0.544976     -0.996291           -0.150251
# 2     21.9038  -2.379864      1.441576           -0.150251
# 3     23.8712   2.174468     -0.362170            0.490702
# 4     21.9603   1.117231     -0.996291            1.745320
# ..        ...        ...           ...                 ...
# 902   16.2949   0.153591     -0.996291            1.875770
# 903   12.8932   0.332870      1.171313           -0.150251
# 904   15.2758  -0.280819      1.441576           -0.150251
# 905   24.3500  -0.796374     -0.996291           -0.150251
# 906    9.9344   0.180889      1.441576           -0.150251
#
#      generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0               0.287071             0.311796             0.315787
# 1               0.287071             0.311796             0.315787
# ...

# %%
gpp.shape
# Out:
# (907, 11)

# %%
gpp_2.shape
# Out:
# (885, 11)

# %%
data_lost = (gpp.shape[0]-gpp_2.shape[0])/gpp.shape[0]*100
data_lost
# Out:
# 2.4255788313120177

# %% [markdown]
# - Only 2.42 % data is lost while using z score method . Therby , going ahead with this method .

# %% [markdown]
# #### CHECKING MULTICOLLINEARITY-

# %%
x = gpp_2.drop('capacity_mw',axis = 1)
y = gpp_2['capacity_mw']
z = x.columns

# %%
# scalling the data using standard scaler -

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x = sc.fit_transform(x)
x = pd.DataFrame(x,columns = z)
x
# Out:
#      latitude  longitude  primary_fuel  commissioning_year  \
# 0    1.140927  -0.943711      1.147391            1.279089
# 1    0.583590  -0.533689     -1.019415           -0.135936
# 2    0.116777  -2.379624      1.417555           -0.135936
# 3    0.437618   2.202128     -0.385527            0.510736
# 4    0.125991   1.138526     -1.019415            1.776549
# ..        ...        ...           ...                 ...
# 880 -0.797914   0.169084     -1.019415            1.908164
# 881 -1.352658   0.349442      1.147391           -0.135936
# 882 -0.964108  -0.267942      1.417555           -0.135936
# 883  0.515700  -0.786601     -1.019415           -0.135936
# 884 -1.835175   0.196547      1.417555           -0.135936
#
#      generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0               0.387876             0.414785             0.417438
# 1               0.387876             0.414785             0.417438
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def vifscore(x):
    vif = pd.DataFrame()
    vif['Column Name'] = x.columns
    vif['VIF Factor'] = [variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    return(vif.sort_values('VIF Factor',ascending = False))

# %%
vifscore(x)
# Out:
#            Column Name  VIF Factor
# 6  generation_gwh_2016   11.676355
# 8  generation_gwh_2018   11.006864
# 7  generation_gwh_2017    9.813509
# 5  generation_gwh_2015    7.426308
# 4  generation_gwh_2014    4.012038
# 1            longitude    1.190220
# 2         primary_fuel    1.168739
# 3   commissioning_year    1.096934
# 9          other_fuel1    1.025858
# 0             latitude    1.020278

# %% [markdown]
# - There is multicollinearity present in 'generation_gwh_2016' and 'generation_gwh_2018'.But since we cannot lose more data , so we consider keeping it.

# %% [markdown]
# ### MODEL BUILDING-
# #### (REGRESSION)

# %%
x = x.copy()
y = y.copy()

# %%
#Model 
from sklearn.model_selection import train_test_split,GridSearchCV

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import ExtraTreesRegressor
from xgboost import XGBRegressor

#Reguralization technique
from sklearn.linear_model import Lasso,Ridge,ElasticNet

from sklearn.model_selection import cross_val_score

#Metrics 
from sklearn.metrics import mean_squared_error,mean_absolute_error, r2_score

# %%
lr = LinearRegression()
knn = KNeighborsRegressor()
svr = SVR()
dtr = DecisionTreeRegressor()
rfr = RandomForestRegressor(n_estimators=100)
abr = AdaBoostRegressor()
gbr = GradientBoostingRegressor()
sgd = SGDRegressor()
etr = ExtraTreesRegressor()
xgb = XGBRegressor()

# %% [markdown]
# #### Finding best random state

# %%
maxacc = 0
maxrs = 0
for i in range(1,100):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.20, random_state = i)
   
    rfr.fit(x_train,y_train)
    pred = rfr.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc>maxacc:
        maxacc = acc
        maxrs = i
print(f"Best Accuracy is: {maxacc} on random_state: {maxrs}")
# Out:
# Best Accuracy is: 0.8932876608122126 on random_state: 47

# %%
#Applying the best selected random state -

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.20, random_state = 47)

# %%
def mod_test(model):
    model
    print(model)
    model.fit(x_train,y_train)
    pred_test = model.predict(x_test)
    acc = r2_score(y_test,pred_test)
    mse = mean_squared_error(y_test,pred_test)
    mae = mean_absolute_error(y_test,pred_test)
    print("R2 score is ", acc)
    print("_"*50)
    print("Mean Sqaured Error is ",mse)
    print("_"*50)
    print("Mean Absolute Error is ",mae)
    print("_"*50)
    print("Coefficent is ",lr.coef_)
    print("_"*50)
    print("Intercept is ",lr.intercept_)
    print("_"*50)

# %% [markdown]
# ### 1) LINEAR REGRESSION

# %%
mod_test(lr)
# Out:
# LinearRegression()
# R2 score is  0.24595144338720176
# __________________________________________________
# Mean Sqaured Error is  123758.02163675583
# __________________________________________________
# Mean Absolute Error is  271.7823800557974
# __________________________________________________
# Coefficent is  [   6.90914822   67.4220115  -123.01336719   93.88918739    3.15308128
#   -62.85814408   95.45481469   71.55857928   29.53488078  -31.58539865]
# __________________________________________________
# Intercept is  269.4656446621654
# __________________________________________________

# %% [markdown]
# ##

# %% [markdown]
# ### 2) KNN REGRESSOR

# %%
mod_test(knn)
# Out:
# KNeighborsRegressor()
# R2 score is  0.80648167505263
# __________________________________________________
# Mean Sqaured Error is  31761.144339996838
# __________________________________________________
# Mean Absolute Error is  89.98473898305085
# __________________________________________________
# Coefficent is  [   6.90914822   67.4220115  -123.01336719   93.88918739    3.15308128
#   -62.85814408   95.45481469   71.55857928   29.53488078  -31.58539865]
# __________________________________________________
# Intercept is  269.4656446621654
# __________________________________________________

# %% [markdown]
# ### 3) SVR

# %%
mod_test(svr)
# Out:
# SVR()
# R2 score is  -0.1596370250049013
# __________________________________________________
# Mean Sqaured Error is  190325.1226632
# __________________________________________________
# Mean Absolute Error is  219.59965793509687
# __________________________________________________
# Coefficent is  [   6.90914822   67.4220115  -123.01336719   93.88918739    3.15308128
#   -62.85814408   95.45481469   71.55857928   29.53488078  -31.58539865]
# __________________________________________________
# Intercept is  269.4656446621654
# __________________________________________________

# %% [markdown]
# ### 4)DECISION TREE REGRESSOR

# %%
mod_test(dtr)
# Out:
# DecisionTreeRegressor()
# R2 score is  0.7225951831119605
# __________________________________________________
# Mean Sqaured Error is  45528.992834077115
# __________________________________________________
# Mean Absolute Error is  107.05924511082137
# __________________________________________________
# Coefficent is  [   6.90914822   67.4220115  -123.01336719   93.88918739    3.15308128
#   -62.85814408   95.45481469   71.55857928   29.53488078  -31.58539865]
# __________________________________________________
# Intercept is  269.4656446621654
# __________________________________________________

# %% [markdown]
# ### 5)RANDOM FOREST REGRESSOR

# %%
mod_test(rfr)
# Out:
# RandomForestRegressor()
# R2 score is  0.8933146710971618
# __________________________________________________
# Mean Sqaured Error is  17509.701632466167
# __________________________________________________
# Mean Absolute Error is  66.25360676869022
# __________________________________________________
# Coefficent is  [   6.90914822   67.4220115  -123.01336719   93.88918739    3.15308128
#   -62.85814408   95.45481469   71.55857928   29.53488078  -31.58539865]
# __________________________________________________
# Intercept is  269.4656446621654
# __________________________________________________

# %% [markdown]
# ### 6)ADABOOST REGRESSOR

# %%
mod_test(abr)
# Out:
# AdaBoostRegressor()
# R2 score is  0.7478085535395238
# __________________________________________________
# Mean Sqaured Error is  41390.85502379254
# __________________________________________________
# Mean Absolute Error is  184.6509216781772
# __________________________________________________
# Coefficent is  [   6.90914822   67.4220115  -123.01336719   93.88918739    3.15308128
#   -62.85814408   95.45481469   71.55857928   29.53488078  -31.58539865]
# __________________________________________________
# Intercept is  269.4656446621654
# __________________________________________________

# %% [markdown]
# ### 7) GRADIENTBOOSTING REGRESSOR

# %%
mod_test(gbr)
# Out:
# GradientBoostingRegressor()
# R2 score is  0.8839689719642014
# __________________________________________________
# Mean Sqaured Error is  19043.562052149216
# __________________________________________________
# Mean Absolute Error is  77.85556451665423
# __________________________________________________
# Coefficent is  [   6.90914822   67.4220115  -123.01336719   93.88918739    3.15308128
#   -62.85814408   95.45481469   71.55857928   29.53488078  -31.58539865]
# __________________________________________________
# Intercept is  269.4656446621654
# __________________________________________________

# %% [markdown]
# ### 8) SGDRegressor

# %%
mod_test(sgd)
# Out:
# SGDRegressor()
# R2 score is  0.25752040849059643
# __________________________________________________
# Mean Sqaured Error is  121859.26827263263
# __________________________________________________
# Mean Absolute Error is  270.43763899134365
# __________________________________________________
# Coefficent is  [   6.90914822   67.4220115  -123.01336719   93.88918739    3.15308128
#   -62.85814408   95.45481469   71.55857928   29.53488078  -31.58539865]
# __________________________________________________
# Intercept is  269.4656446621654
# __________________________________________________

# %% [markdown]
# ### 9) EXTRA TREE REGRESSOR

# %%
mod_test(etr)
# Out:
# ExtraTreesRegressor()
# R2 score is  0.8884552168727211
# __________________________________________________
# Mean Sqaured Error is  18307.258282866278
# __________________________________________________
# Mean Absolute Error is  67.70014721425468
# __________________________________________________
# Coefficent is  [   6.90914822   67.4220115  -123.01336719   93.88918739    3.15308128
#   -62.85814408   95.45481469   71.55857928   29.53488078  -31.58539865]
# __________________________________________________
# Intercept is  269.4656446621654
# __________________________________________________

# %% [markdown]
# ### 10) XGBRegressor

# %%
mod_test(xgb)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# R2 score is  0.8627439604813509
# __________________________________________________
# Mean Sqaured Error is  22527.111496411133
# __________________________________________________
# Mean Absolute Error is  76.62186907539798
# ...

# %% [markdown]
# ## CROSS-VALIDATION

# %%
print('\n=========CV SCORE=========\n')
print('cross validation score of Linear regression',cross_val_score(lr,x,y,scoring='r2').mean()*100)
# Out:
# =========CV SCORE=========
#
# cross validation score of Linear regression 27.157292531996298

# %%
print('\n=========CV SCORE=========\n')
print('cross validation score of knn',cross_val_score(knn,x,y,scoring='r2').mean()*100)
# Out:
# =========CV SCORE=========
#
# cross validation score of knn 68.30156094106691

# %%
print('\n=========CV SCORE=========\n')
print('cross validation score of RFR',cross_val_score(rfr,x,y,scoring='r2').mean()*100)
# Out:
# =========CV SCORE=========
#
# cross validation score of RFR 78.76018213149761

# %%
print('\n=========CV SCORE=========\n')
print('cross validation score of gbr',cross_val_score(gbr,x,y,scoring='r2').mean()*100)
# Out:
# =========CV SCORE=========
#
# cross validation score of gbr 76.37712697365663

# %%
print('\n=========CV SCORE=========\n')
print('cross validation score of svr',cross_val_score(svr,x,y,scoring='r2').mean()*100)
# Out:
# =========CV SCORE=========
#
# cross validation score of svr -17.74030609626848

# %%
print('\n=========CV SCORE=========\n')
print('cross validation score of dtr',cross_val_score(dtr,x,y,scoring='r2').mean()*100)
# Out:
# =========CV SCORE=========
#
# cross validation score of dtr 60.49557769220482

# %%
print('\n=========CV SCORE=========\n')
print('cross validation score of ADA',cross_val_score(abr,x,y,scoring='r2').mean()*100)
# Out:
# =========CV SCORE=========
#
# cross validation score of ADA 58.89958744150097

# %%
print('\n=========CV SCORE=========\n')
print('cross validation score of SBD regressor',cross_val_score(sgd,x,y,scoring='r2').mean()*100)
# Out:
# =========CV SCORE=========
#
# cross validation score of SBD regressor 27.036504750377215

# %%
print('\n=========CV SCORE=========\n')
print('cross validation score of ETR',cross_val_score(etr,x,y,scoring='r2').mean()*100)
# Out:
# =========CV SCORE=========
#
# cross validation score of ETR 79.99667562371721

# %%
print('\n=========CV SCORE=========\n')
print('cross validation score of XGB REGRESSOR',cross_val_score(xgb,x,y,scoring='r2').mean()*100)
# Out:
# =========CV SCORE=========
#
# cross validation score of XGB REGRESSOR 74.1486512658453

# %% [markdown]
# #### - So after performing cross validations, the ExtraTree Regressor is performing well and giving the maximum cross validation mean score of 79.99 %  with an R2 Score of 88.84 %.
# - Moreover, we can also see that the RandomForest Regressor is also performing well by giving the maximum R2 Score of 89.33% with a cross validation score of 78.76%.

# %% [markdown]
# ### HYPERPARAMETER TUNNING OF RFR GBR

# %% [markdown]
# ### RandomForestRegressor(rfr)

# %%
parameters = {'n_estimators':[100,125,150,200],
             'criterion': ['squared_error','absolute_error'],
             'max_features': ['sqrt','log2'],
             'max_depth':[10,20,30,None]}

grid = GridSearchCV(estimator = RandomForestRegressor(),param_grid=parameters, cv = 5)

# %%
grid.fit(x,y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_depth': [10, 20, 30, None],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [100, 125, 150, 200]})

# %%
grid.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 'log2',
#  'n_estimators': 125}

# %%
rfr = RandomForestRegressor(n_estimators=125,max_depth= None,max_features='log2',criterion='squared_error')
x_train, x_test,y_train,y_test= train_test_split(x,y,test_size = 0.20, random_state = 47)
rfr.fit(x_train,y_train)
pred = rfr.predict(x_test)

cv_score = cross_val_score(rfr,x,y, cv = 5)
cv_mean =cv_score.mean()
print("At cv fold",5," the cv score is ", cv_mean, "and the R2 score  is ",r2_score(y_test,pred))

print('R2 Score',r2_score(y_test,pred))
print('Mean Squared Error',mean_squared_error(y_test,pred))
print('Mean Absolute Error',mean_absolute_error(y_test,pred))
# Out:
# At cv fold 5  the cv score is  0.8031391629391365 and the R2 score  is  0.902095117876762
# R2 Score 0.902095117876762
# Mean Squared Error 16068.613107064823
# Mean Absolute Error 65.63855977991729

# %% [markdown]
# #### EXTRA TREE REGRESSOR

# %%
parameters = {'n_estimators':[100,125,150,200],
             'criterion': ['squared_error','absolute_error'],
             'max_features': [None,'sqrt','log2'],
             'max_depth':[10,20,30,None]}

grid = GridSearchCV(estimator = ExtraTreesRegressor(),param_grid=parameters, cv = 5)

# %%
grid.fit(x,y)
grid.best_params_
# Out:
# {'criterion': 'absolute_error',
#  'max_depth': None,
#  'max_features': 'log2',
#  'n_estimators': 150}

# %%
etr = ExtraTreesRegressor(n_estimators=150,max_depth=None,max_features='log2',criterion='absolute_error')
x_train, x_test,y_train,y_test= train_test_split(x,y,test_size = 0.20, random_state = 47)
etr.fit(x_train,y_train)
predetr = etr.predict(x_test)

cv_score = cross_val_score(etr,x,y, cv = 5)
cv_mean =cv_score.mean()
print("At cv fold",5," the cv score is ", cv_mean, "and the R2 score  is ",r2_score(y_test,predetr))

print('R2 Score',r2_score(y_test,predetr))
print('Mean Squared Error',mean_squared_error(y_test,predetr))
print('Mean Absolute Error',mean_absolute_error(y_test,predetr))
# Out:
# At cv fold 5  the cv score is  0.8040905555550802 and the R2 score  is  0.8779026872554608
# R2 Score 0.8779026872554608
# Mean Squared Error 20039.18943934486
# Mean Absolute Error 69.44985220338984

# %% [markdown]
# ### After the hyper parameter tuning the RandomForestRegressor(rfr) is slightly performing better than the ExtraTreeRegressor(etr). So we will consider the rfr model as the best model
#
# # The RANDOM FOREST REGRESSOR Model is giving accuracy of 90.20 after hyperparameter tunning .

# %% [markdown]
# ### SAVING THE MODEL -

# %%
import pickle

filename = 'Global powerplant prediction model-regression.pkl'
pickle.dump(rfr,open(filename,'wb'))

# %% [markdown]
# ### CONCLUSION-

# %%
actual = np.array(y_test)
predicted = np.round(np.array(rfr.predict(x_test)),2)

prediction_test = pd.DataFrame({'Actual Power plant-capacity_mw':actual,'Predicted Power plant- capacity_mw':predicted})
prediction_test.head(10)
# Out:
#    Actual Power plant-capacity_mw  Predicted Power plant- capacity_mw
# 0                            20.0                               23.58
# 1                          1200.0                             1295.25
# 2                            24.0                               27.77
# 3                            30.6                               48.56
# 4                           192.0                              183.32
# 5                            12.0                                9.54
# 6                          1000.0                             1142.15
# 7                           500.0                              277.96
# 8                           180.0                              252.48
# 9                             4.0                               12.58

# %% [markdown]
# # The RANDOM FOREST REGRESSOR model is performing well with predictions with an R2 Score of 90.20%.

# %% [markdown]
# **---------------------------***
